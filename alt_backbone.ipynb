# %%
from torchvision.models.quantization import resnext101_64x4d, ResNeXt101_64X4D_QuantizedWeights
from torchvision.models import ResNeXt101_64X4D_Weights

# %%
pre_quant = resnext101_64x4d(weights=ResNeXt101_64X4D_QuantizedWeights.DEFAULT, quantize=True)
regular = resnext101_64x4d(weights=ResNeXt101_64X4D_Weights.DEFAULT)
# Out:
# Downloading: "https://download.pytorch.org/models/quantized/resnext101_64x4d_fbgemm-605a1cb3.pth" to /home/pcsmet/.cache/torch/hub/checkpoints/resnext101_64x4d_fbgemm-605a1cb3.pth
# 100.0%
# /home/pcsmet/miniconda3/envs/harvard_gf/lib/python3.10/site-packages/torch/_utils.py:403: UserWarning: TypedStorage is deprecated. It will be removed in the future and UntypedStorage will be the only storage class. This should only matter to you if you are using storages directly.  To access UntypedStorage directly, use tensor.untyped_storage() instead of tensor.storage()
#   device=storage.device,
# Downloading: "https://download.pytorch.org/models/resnext101_64x4d-173b62eb.pth" to /home/pcsmet/.cache/torch/hub/checkpoints/resnext101_64x4d-173b62eb.pth
# 100.0%

# %%
pre_quant
# Out:
# QuantizableResNet(
#   (conv1): QuantizedConvReLU2d(3, 64, kernel_size=(7, 7), stride=(2, 2), scale=0.26095113158226013, zero_point=0, padding=(3, 3))
#   (bn1): Identity()
#   (relu): Identity()
#   (maxpool): MaxPool2d(kernel_size=3, stride=2, padding=1, dilation=1, ceil_mode=False)
#   (layer1): Sequential(
#     (0): QuantizableBottleneck(
#       (conv1): QuantizedConvReLU2d(64, 256, kernel_size=(1, 1), stride=(1, 1), scale=0.11144866794347763, zero_point=0)
#       (bn1): Identity()
#       (conv2): QuantizedConvReLU2d(256, 256, kernel_size=(3, 3), stride=(1, 1), scale=0.1748036891222, zero_point=0, padding=(1, 1), groups=64)
#       (bn2): Identity()
#       (conv3): QuantizedConv2d(256, 256, kernel_size=(1, 1), stride=(1, 1), scale=0.2295544147491455, zero_point=72)
#       (bn3): Identity()
#       (relu): ReLU()
#       (downsample): Sequential(
#         (0): QuantizedConv2d(64, 256, kernel_size=(1, 1), stride=(1, 1), scale=0.30945485830307007, zero_point=76)
# ...

# %%
regular
# Out:
# QuantizableResNet(
#   (conv1): Conv2d(3, 64, kernel_size=(7, 7), stride=(2, 2), padding=(3, 3), bias=False)
#   (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (relu): ReLU()
#   (maxpool): MaxPool2d(kernel_size=3, stride=2, padding=1, dilation=1, ceil_mode=False)
#   (layer1): Sequential(
#     (0): QuantizableBottleneck(
#       (conv1): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=64, bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU()
#       (downsample): Sequential(
# ...

# %%
ResNeXt101_64X4D_QuantizedWeights.DEFAULT.transforms()
# Out:
# ImageClassification(
#     crop_size=[224]
#     resize_size=[232]
#     mean=[0.485, 0.456, 0.406]
#     std=[0.229, 0.224, 0.225]
#     interpolation=InterpolationMode.BILINEAR
# )

# %%
ResNeXt101_64X4D_Weights.DEFAULT.transforms()
# Out:
# ImageClassification(
#     crop_size=[224]
#     resize_size=[232]
#     mean=[0.485, 0.456, 0.406]
#     std=[0.229, 0.224, 0.225]
#     interpolation=InterpolationMode.BILINEAR
# )
