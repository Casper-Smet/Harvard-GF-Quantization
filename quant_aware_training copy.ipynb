# %%
import os
import argparse
import random
import time
import json

import numpy as np
import torch
import torch.nn as nn
from torch.optim.lr_scheduler import *
from torch.optim import *
import torch.nn.functional as F

from sklearn.metrics import *
from sklearn.model_selection import KFold

import sys
sys.path.append('.')

from src.modules import *
from src.data_handler import *
from src import logger
from src.class_balanced_loss import *
from typing import NamedTuple
from torchvision.models import efficientnet as efn

from train_glaucoma_fair_fin import train, validation, Identity_Info, quantifiable_efficientnet

from fairlearn.metrics import *

imb_info = Identity_Info()

# %%
out_dim = 1
criterion = nn.BCEWithLogitsLoss()
predictor_head = nn.Sigmoid()
in_feat_to_final = 1280
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

fin_mu = 0.01
fin_sigma = 1.
fin_momentum = 0.3
model_type = 'resnext'# 'resnext'  # or quant
modality_types = 'rnflt'
task = 'cls'
pretrained_weights = 'results/crosssectional_rnflt_fin_race_ablation_of_sigma/fullysup_quant_rnflt_Taskcls_lr5e-5_bz6_4442_auc0.7311/best_weights.pth'
pretrained_weights = 'results/crosssectional_rnflt_fin_race_ablation_of_sigma/fullysup_resnext_rnflt_Taskcls_lr5e-5_bz6_3162_auc0.8324/best_weights.pth'
if model_type == 'resnext':
    pretrained_weights = 'results/crosssectional_rnflt_fin_race_ablation_of_sigma/fullysup_resnext_rnflt_Taskcls_lr5e-5_bz6_865_auc0.8510/last_weights.pth'
else:
    pretrained_weights = 'results/crosssectional_rnflt_fin_race_ablation_of_sigma/fullysup_quant_rnflt_Taskcls_lr5e-5_bz6_9354_auc0.8495/best_weights.pth'

ag_norm = Fair_Identity_Normalizer(
    3,
    dim=in_feat_to_final,
    mu=fin_mu,
    sigma=fin_sigma,
    momentum=fin_momentum,
)
in_dim = 1
# model = quantifiable_efficientnet(width_mult=1.0, depth_mult=1.0, weights=EfficientNet_B1_Weights.IMAGENET1K_V2)# create_model(model_type=model_type, in_dim=in_dim, out_dim=out_dim, include_final=False)
model = create_model(model_type=model_type, in_dim=in_dim, out_dim=out_dim, include_final=False)
final_layer = nn.Linear(in_features=in_feat_to_final, out_features=out_dim, bias=False)
model = nn.Sequential(model, ag_norm, final_layer)
model = model.to(device)

checkpoint = torch.load(pretrained_weights)

start_epoch = checkpoint['epoch'] + 1
model.load_state_dict(checkpoint['model_state_dict'])
# efnm = create_model(model_type=model_type, in_dim=in_dim, out_dim=out_dim, include_final=False)
# optimizer.load_state_dict(checkpoint['optimizer_state_dict'])
# scaler.load_state_dict(checkpoint['scaler_state_dict'])
# scheduler.load_state_dict(checkpoint['scheduler_state_dict'])
# Out:
# <All keys matched successfully>

# %%
data_dir = "../quant_notes/data_cmpr"
image_size = 200
attribute_type = "race"

trn_dataset = EyeFair(
    os.path.join(data_dir, "train"),
    modality_type=modality_types,
    task=task,
    resolution=image_size,
    attribute_type=attribute_type,
    depth=3 if model_type == "resnext" else 1,
)
tst_dataset = EyeFair(
    os.path.join(data_dir, "test"),
    modality_type=modality_types,
    task=task,
    resolution=image_size,
    attribute_type=attribute_type,
    depth=3 if model_type == "resnext" else 1,
)

batch_size = 6
workers = 1

train_dataset_loader = torch.utils.data.DataLoader(
    trn_dataset,
    batch_size=batch_size,
    shuffle=True,
    num_workers=workers,
    pin_memory=True,
    drop_last=True,
)

validation_dataset_loader = torch.utils.data.DataLoader(
    tst_dataset,
    batch_size=batch_size,
    shuffle=False,
    num_workers=workers,
    pin_memory=True,
    drop_last=False,
)
# Out:
# min: -31.9900, max: 2.2700
# min: -31.1600, max: 2.5300

# %%
for i in train_dataset_loader:
    print(i[0].dtype)
    break
# Out:
# torch.float32

# %%
from copy import deepcopy

import torch.ao.quantization
qmodel = deepcopy(model).to('cpu')
if model_type == 'resnext':
    qmodel[0].fuse_model(is_qat=True)
else:
    qmodel[0] = torch.quantization.QuantWrapper(qmodel[0])
qmodel[1].v = False
# qmodel = torch.ao.quantization.fuse_modules(model, ['conv2', 'bn2'])
qmodel[2] = torch.quantization.QuantWrapper(qmodel[2])
qmodel.qconfig = torch.ao.quantization.default_per_channel_qconfig
torch.ao.quantization.prepare_qat(qmodel, inplace=True)
print(qmodel.qconfig)
qmodel
# Out:
# QConfig(activation=functools.partial(<class 'torch.ao.quantization.observer.MinMaxObserver'>, quant_min=0, quant_max=127){'factory_kwargs': <function _add_module_to_qconfig_obs_ctr.<locals>.get_factory_kwargs_based_on_module_device at 0x7f0664439ea0>}, weight=functools.partial(<class 'torch.ao.quantization.observer.PerChannelMinMaxObserver'>, dtype=torch.qint8, qscheme=torch.per_channel_symmetric){'factory_kwargs': <function _add_module_to_qconfig_obs_ctr.<locals>.get_factory_kwargs_based_on_module_device at 0x7f0664439ea0>})

# %%
# scaler = torch.cuda.amp.GradScaler()
scaler = None

optimizer = AdamW(qmodel.parameters(), lr=5e-5, betas=(0.0, 0.1), weight_decay=0.)

scheduler = StepLR(optimizer, step_size=30, gamma=0.1)

for epoch in range(start_epoch, start_epoch+1):
    train_loss, train_acc, train_auc, trn_preds, trn_gts, trn_attrs, trn_pred_gt_by_attrs, trn_other_metrics = train(qmodel, criterion, optimizer, scaler, train_dataset_loader, epoch, None, identity_Info=imb_info, time_window=-1, _device='cpu')
    test_loss, test_acc, test_auc, tst_preds, tst_gts, tst_attrs, tst_pred_gt_by_attrs, tst_other_metrics = validation(qmodel, criterion, optimizer, validation_dataset_loader, epoch, identity_Info=imb_info, _device='cpu')
    scheduler.step()
# Out:
# 349train ====> epcoh 4 loss: 0.2247 auc: 0.9806 time: 1769.8557
# 0-attr auc: 0.9746
# 1-attr auc: 0.9848
# 2-attr auc: 0.9816
# cpu
# test <==== epcoh 4 loss: 7.2842 auc: 0.7964
# 0-attr auc: 0.8400
# 1-attr auc: 0.7598
# 2-attr auc: 0.7760

# %%
qmodel.eval()
torch.quantization.convert(qmodel, inplace=True)
# Out:
# Sequential(
#   (0): QuantizableResNet(
#     (conv1): QuantizedConvReLU2d(3, 64, kernel_size=(7, 7), stride=(2, 2), scale=1.6556651592254639, zero_point=0, padding=(3, 3))
#     (bn1): Identity()
#     (relu): Identity()
#     (maxpool): MaxPool2d(kernel_size=3, stride=2, padding=1, dilation=1, ceil_mode=False)
#     (layer1): Sequential(
#       (0): QuantizableBottleneck(
#         (conv1): QuantizedConvReLU2d(64, 256, kernel_size=(1, 1), stride=(1, 1), scale=0.815531849861145, zero_point=0)
#         (bn1): Identity()
#         (conv2): QuantizedConvReLU2d(256, 256, kernel_size=(3, 3), stride=(1, 1), scale=1.0254476070404053, zero_point=0, padding=(1, 1), groups=64)
#         (bn2): Identity()
#         (conv3): QuantizedConv2d(256, 256, kernel_size=(1, 1), stride=(1, 1), scale=1.6215773820877075, zero_point=79)
#         (bn3): Identity()
#         (relu): ReLU()
#         (downsample): Sequential(
#           (0): QuantizedConv2d(64, 256, kernel_size=(1, 1), stride=(1, 1), scale=2.743269681930542, zero_point=83)
#           (1): Identity()
#         )
#         (skip_add_relu): QFunctional(
#           scale=0.874716579914093, zero_point=0
#           (activation_post_process): Identity()
#         )
#         (relu1): Identity()
#         (relu2): Identity()
#       )
#       (1): QuantizableBottleneck(
#         (conv1): QuantizedConvReLU2d(256, 256, kernel_size=(1, 1), stride=(1, 1), scale=0.7900527119636536, zero_point=0)
#         (bn1): Identity()
#         (conv2): QuantizedConvReLU2d(256, 256, kernel_size=(3, 3), stride=(1, 1), scale=2.6190836429595947, zero_point=0, padding=(1, 1), groups=64)
#         (bn2): Identity()
#         (conv3): QuantizedConv2d(256, 256, kernel_size=(1, 1), stride=(1, 1), scale=5.868001461029053, zero_point=30)
#         (bn3): Identity()
#         (relu): ReLU()
#         (skip_add_relu): QFunctional(
#           scale=4.485380172729492, zero_point=0
#           (activation_post_process): Identity()
#         )
#         (relu1): Identity()
#         (relu2): Identity()
#       )
#       (2): QuantizableBottleneck(
#         (conv1): QuantizedConvReLU2d(256, 256, kernel_size=(1, 1), stride=(1, 1), scale=2.246783494949341, zero_point=0)
#         (bn1): Identity()
#         (conv2): QuantizedConvReLU2d(256, 256, kernel_size=(3, 3), stride=(1, 1), scale=4.063265323638916, zero_point=0, padding=(1, 1), groups=64)
#         (bn2): Identity()
#         (conv3): QuantizedConv2d(256, 256, kernel_size=(1, 1), stride=(1, 1), scale=7.718369007110596, zero_point=69)
#         (bn3): Identity()
#         (relu): ReLU()
#         (skip_add_relu): QFunctional(
#           scale=3.521969795227051, zero_point=0
#           (activation_post_process): Identity()
#         )
#         (relu1): Identity()
#         (relu2): Identity()
#       )
#     )
#     (layer2): Sequential(
#       (0): QuantizableBottleneck(
#         (conv1): QuantizedConvReLU2d(256, 512, kernel_size=(1, 1), stride=(1, 1), scale=1.2419991493225098, zero_point=0)
#         (bn1): Identity()
#         (conv2): QuantizedConvReLU2d(512, 512, kernel_size=(3, 3), stride=(2, 2), scale=29.532745361328125, zero_point=0, padding=(1, 1), groups=64)
#         (bn2): Identity()
#         (conv3): QuantizedConv2d(512, 512, kernel_size=(1, 1), stride=(1, 1), scale=81.59773254394531, zero_point=85)
#         (bn3): Identity()
#         (relu): ReLU()
#         (downsample): Sequential(
#           (0): QuantizedConv2d(256, 512, kernel_size=(1, 1), stride=(2, 2), scale=2.3849847316741943, zero_point=81)
#           (1): Identity()
#         )
#         (skip_add_relu): QFunctional(
#           scale=26.608301162719727, zero_point=0
#           (activation_post_process): Identity()
#         )
#         (relu1): Identity()
#         (relu2): Identity()
#       )
#       (1): QuantizableBottleneck(
#         (conv1): QuantizedConvReLU2d(512, 512, kernel_size=(1, 1), stride=(1, 1), scale=13.598922729492188, zero_point=0)
#         (bn1): Identity()
#         (conv2): QuantizedConvReLU2d(512, 512, kernel_size=(3, 3), stride=(1, 1), scale=68.94039916992188, zero_point=0, padding=(1, 1), groups=64)
#         (bn2): Identity()
#         (conv3): QuantizedConv2d(512, 512, kernel_size=(1, 1), stride=(1, 1), scale=97.80097198486328, zero_point=43)
#         (bn3): Identity()
#         (relu): ReLU()
#         (skip_add_relu): QFunctional(
#           scale=84.00291442871094, zero_point=0
#           (activation_post_process): Identity()
#         )
#         (relu1): Identity()
#         (relu2): Identity()
#       )
#       (2): QuantizableBottleneck(
#         (conv1): QuantizedConvReLU2d(512, 512, kernel_size=(1, 1), stride=(1, 1), scale=48.32603454589844, zero_point=0)
#         (bn1): Identity()
#         (conv2): QuantizedConvReLU2d(512, 512, kernel_size=(3, 3), stride=(1, 1), scale=89.77838897705078, zero_point=0, padding=(1, 1), groups=64)
#         (bn2): Identity()
#         (conv3): QuantizedConv2d(512, 512, kernel_size=(1, 1), stride=(1, 1), scale=470.6556091308594, zero_point=70)
#         (bn3): Identity()
#         (relu): ReLU()
#         (skip_add_relu): QFunctional(
#           scale=210.19776916503906, zero_point=0
#           (activation_post_process): Identity()
#         )
#         (relu1): Identity()
#         (relu2): Identity()
#       )
#       (3): QuantizableBottleneck(
#         (conv1): QuantizedConvReLU2d(512, 512, kernel_size=(1, 1), stride=(1, 1), scale=41.444557189941406, zero_point=0)
#         (bn1): Identity()
#         (conv2): QuantizedConvReLU2d(512, 512, kernel_size=(3, 3), stride=(1, 1), scale=62.84534454345703, zero_point=0, padding=(1, 1), groups=64)
#         (bn2): Identity()
#         (conv3): QuantizedConv2d(512, 512, kernel_size=(1, 1), stride=(1, 1), scale=233.03907775878906, zero_point=110)
#         (bn3): Identity()
#         (relu): ReLU()
#         (skip_add_relu): QFunctional(
#           scale=146.80606079101562, zero_point=0
#           (activation_post_process): Identity()
#         )
#         (relu1): Identity()
#         (relu2): Identity()
#       )
#     )
#     (layer3): Sequential(
#       (0): QuantizableBottleneck(
#         (conv1): QuantizedConvReLU2d(512, 1024, kernel_size=(1, 1), stride=(1, 1), scale=31.44428253173828, zero_point=0)
#         (bn1): Identity()
#         (conv2): QuantizedConvReLU2d(1024, 1024, kernel_size=(3, 3), stride=(2, 2), scale=109.56436157226562, zero_point=0, padding=(1, 1), groups=64)
#         (bn2): Identity()
#         (conv3): QuantizedConv2d(1024, 1024, kernel_size=(1, 1), stride=(1, 1), scale=162.97434997558594, zero_point=57)
#         (bn3): Identity()
#         (relu): ReLU()
#         (downsample): Sequential(
#           (0): QuantizedConv2d(512, 1024, kernel_size=(1, 1), stride=(2, 2), scale=93.9640121459961, zero_point=73)
#           (1): Identity()
#         )
#         (skip_add_relu): QFunctional(
#           scale=129.23890686035156, zero_point=0
#           (activation_post_process): Identity()
#         )
#         (relu1): Identity()
#         (relu2): Identity()
#       )
#       (1): QuantizableBottleneck(
#         (conv1): QuantizedConvReLU2d(1024, 1024, kernel_size=(1, 1), stride=(1, 1), scale=49.80711364746094, zero_point=0)
#         (bn1): Identity()
#         (conv2): QuantizedConvReLU2d(1024, 1024, kernel_size=(3, 3), stride=(1, 1), scale=69.27278137207031, zero_point=0, padding=(1, 1), groups=64)
#         (bn2): Identity()
#         (conv3): QuantizedConv2d(1024, 1024, kernel_size=(1, 1), stride=(1, 1), scale=444.5333251953125, zero_point=88)
#         (bn3): Identity()
#         (relu): ReLU()
#         (skip_add_relu): QFunctional(
#           scale=137.06210327148438, zero_point=0
#           (activation_post_process): Identity()
#         )
#         (relu1): Identity()
#         (relu2): Identity()
#       )
#       (2): QuantizableBottleneck(
#         (conv1): QuantizedConvReLU2d(1024, 1024, kernel_size=(1, 1), stride=(1, 1), scale=23.92812156677246, zero_point=0)
#         (bn1): Identity()
#         (conv2): QuantizedConvReLU2d(1024, 1024, kernel_size=(3, 3), stride=(1, 1), scale=29.16495132446289, zero_point=0, padding=(1, 1), groups=64)
#         (bn2): Identity()
#         (conv3): QuantizedConv2d(1024, 1024, kernel_size=(1, 1), stride=(1, 1), scale=224.01025390625, zero_point=66)
#         (bn3): Identity()
#         (relu): ReLU()
#         (skip_add_relu): QFunctional(
#           scale=108.37606811523438, zero_point=0
#           (activation_post_process): Identity()
#         )
#         (relu1): Identity()
#         (relu2): Identity()
#       )
#       (3): QuantizableBottleneck(
#         (conv1): QuantizedConvReLU2d(1024, 1024, kernel_size=(1, 1), stride=(1, 1), scale=13.337807655334473, zero_point=0)
#         (bn1): Identity()
#         (conv2): QuantizedConvReLU2d(1024, 1024, kernel_size=(3, 3), stride=(1, 1), scale=31.087993621826172, zero_point=0, padding=(1, 1), groups=64)
#         (bn2): Identity()
#         (conv3): QuantizedConv2d(1024, 1024, kernel_size=(1, 1), stride=(1, 1), scale=197.65530395507812, zero_point=70)
#         (bn3): Identity()
#         (relu): ReLU()
#         (skip_add_relu): QFunctional(
#           scale=92.6139907836914, zero_point=0
#           (activation_post_process): Identity()
#         )
#         (relu1): Identity()
#         (relu2): Identity()
#       )
#       (4): QuantizableBottleneck(
#         (conv1): QuantizedConvReLU2d(1024, 1024, kernel_size=(1, 1), stride=(1, 1), scale=19.261001586914062, zero_point=0)
#         (bn1): Identity()
#         (conv2): QuantizedConvReLU2d(1024, 1024, kernel_size=(3, 3), stride=(1, 1), scale=41.357688903808594, zero_point=0, padding=(1, 1), groups=64)
#         (bn2): Identity()
#         (conv3): QuantizedConv2d(1024, 1024, kernel_size=(1, 1), stride=(1, 1), scale=269.0842590332031, zero_point=34)
#         (bn3): Identity()
#         (relu): ReLU()
#         (skip_add_relu): QFunctional(
#           scale=197.94735717773438, zero_point=0
#           (activation_post_process): Identity()
#         )
#         (relu1): Identity()
#         (relu2): Identity()
#       )
#       (5): QuantizableBottleneck(
#         (conv1): QuantizedConvReLU2d(1024, 1024, kernel_size=(1, 1), stride=(1, 1), scale=43.19827651977539, zero_point=0)
#         (bn1): Identity()
#         (conv2): QuantizedConvReLU2d(1024, 1024, kernel_size=(3, 3), stride=(1, 1), scale=106.6877670288086, zero_point=0, padding=(1, 1), groups=64)
#         (bn2): Identity()
#         (conv3): QuantizedConv2d(1024, 1024, kernel_size=(1, 1), stride=(1, 1), scale=251.8468017578125, zero_point=78)
#         (bn3): Identity()
#         (relu): ReLU()
#         (skip_add_relu): QFunctional(
#           scale=147.20657348632812, zero_point=0
#           (activation_post_process): Identity()
#         )
#         (relu1): Identity()
#         (relu2): Identity()
#       )
#       (6): QuantizableBottleneck(
#         (conv1): QuantizedConvReLU2d(1024, 1024, kernel_size=(1, 1), stride=(1, 1), scale=27.69989013671875, zero_point=0)
#         (bn1): Identity()
#         (conv2): QuantizedConvReLU2d(1024, 1024, kernel_size=(3, 3), stride=(1, 1), scale=72.97708129882812, zero_point=0, padding=(1, 1), groups=64)
#         (bn2): Identity()
#         (conv3): QuantizedConv2d(1024, 1024, kernel_size=(1, 1), stride=(1, 1), scale=263.13800048828125, zero_point=92)
#         (bn3): Identity()
#         (relu): ReLU()
#         (skip_add_relu): QFunctional(
#           scale=170.36309814453125, zero_point=0
#           (activation_post_process): Identity()
#         )
#         (relu1): Identity()
#         (relu2): Identity()
#       )
#       (7): QuantizableBottleneck(
#         (conv1): QuantizedConvReLU2d(1024, 1024, kernel_size=(1, 1), stride=(1, 1), scale=22.20047378540039, zero_point=0)
#         (bn1): Identity()
#         (conv2): QuantizedConvReLU2d(1024, 1024, kernel_size=(3, 3), stride=(1, 1), scale=44.50529479980469, zero_point=0, padding=(1, 1), groups=64)
#         (bn2): Identity()
#         (conv3): QuantizedConv2d(1024, 1024, kernel_size=(1, 1), stride=(1, 1), scale=150.56590270996094, zero_point=110)
#         (bn3): Identity()
#         (relu): ReLU()
#         (skip_add_relu): QFunctional(
#           scale=185.10951232910156, zero_point=0
#           (activation_post_process): Identity()
#         )
#         (relu1): Identity()
#         (relu2): Identity()
#       )
#       (8): QuantizableBottleneck(
#         (conv1): QuantizedConvReLU2d(1024, 1024, kernel_size=(1, 1), stride=(1, 1), scale=27.317346572875977, zero_point=0)
#         (bn1): Identity()
#         (conv2): QuantizedConvReLU2d(1024, 1024, kernel_size=(3, 3), stride=(1, 1), scale=60.83589553833008, zero_point=0, padding=(1, 1), groups=64)
#         (bn2): Identity()
#         (conv3): QuantizedConv2d(1024, 1024, kernel_size=(1, 1), stride=(1, 1), scale=87.68351745605469, zero_point=79)
#         (bn3): Identity()
#         (relu): ReLU()
#         (skip_add_relu): QFunctional(
#           scale=144.67088317871094, zero_point=0
#           (activation_post_process): Identity()
#         )
#         (relu1): Identity()
#         (relu2): Identity()
#       )
#       (9): QuantizableBottleneck(
#         (conv1): QuantizedConvReLU2d(1024, 1024, kernel_size=(1, 1), stride=(1, 1), scale=15.222168922424316, zero_point=0)
#         (bn1): Identity()
#         (conv2): QuantizedConvReLU2d(1024, 1024, kernel_size=(3, 3), stride=(1, 1), scale=24.545495986938477, zero_point=0, padding=(1, 1), groups=64)
#         (bn2): Identity()
#         (conv3): QuantizedConv2d(1024, 1024, kernel_size=(1, 1), stride=(1, 1), scale=55.87917709350586, zero_point=84)
#         (bn3): Identity()
#         (relu): ReLU()
#         (skip_add_relu): QFunctional(
#           scale=134.9925537109375, zero_point=0
#           (activation_post_process): Identity()
#         )
#         (relu1): Identity()
#         (relu2): Identity()
#       )
#       (10): QuantizableBottleneck(
#         (conv1): QuantizedConvReLU2d(1024, 1024, kernel_size=(1, 1), stride=(1, 1), scale=11.879790306091309, zero_point=0)
#         (bn1): Identity()
#         (conv2): QuantizedConvReLU2d(1024, 1024, kernel_size=(3, 3), stride=(1, 1), scale=57.77962112426758, zero_point=0, padding=(1, 1), groups=64)
#         (bn2): Identity()
#         (conv3): QuantizedConv2d(1024, 1024, kernel_size=(1, 1), stride=(1, 1), scale=65.43147277832031, zero_point=78)
#         (bn3): Identity()
#         (relu): ReLU()
#         (skip_add_relu): QFunctional(
#           scale=135.43319702148438, zero_point=0
#           (activation_post_process): Identity()
#         )
#         (relu1): Identity()
#         (relu2): Identity()
#       )
#       (11): QuantizableBottleneck(
#         (conv1): QuantizedConvReLU2d(1024, 1024, kernel_size=(1, 1), stride=(1, 1), scale=12.861324310302734, zero_point=0)
#         (bn1): Identity()
#         (conv2): QuantizedConvReLU2d(1024, 1024, kernel_size=(3, 3), stride=(1, 1), scale=24.702983856201172, zero_point=0, padding=(1, 1), groups=64)
#         (bn2): Identity()
#         (conv3): QuantizedConv2d(1024, 1024, kernel_size=(1, 1), stride=(1, 1), scale=36.519954681396484, zero_point=86)
#         (bn3): Identity()
#         (relu): ReLU()
#         (skip_add_relu): QFunctional(
#           scale=134.466796875, zero_point=0
#           (activation_post_process): Identity()
#         )
#         (relu1): Identity()
#         (relu2): Identity()
#       )
#       (12): QuantizableBottleneck(
#         (conv1): QuantizedConvReLU2d(1024, 1024, kernel_size=(1, 1), stride=(1, 1), scale=14.8298978805542, zero_point=0)
#         (bn1): Identity()
#         (conv2): QuantizedConvReLU2d(1024, 1024, kernel_size=(3, 3), stride=(1, 1), scale=139.64280700683594, zero_point=0, padding=(1, 1), groups=64)
#         (bn2): Identity()
#         (conv3): QuantizedConv2d(1024, 1024, kernel_size=(1, 1), stride=(1, 1), scale=188.14175415039062, zero_point=99)
#         (bn3): Identity()
#         (relu): ReLU()
#         (skip_add_relu): QFunctional(
#           scale=170.40542602539062, zero_point=0
#           (activation_post_process): Identity()
#         )
#         (relu1): Identity()
#         (relu2): Identity()
#       )
#       (13): QuantizableBottleneck(
#         (conv1): QuantizedConvReLU2d(1024, 1024, kernel_size=(1, 1), stride=(1, 1), scale=5.762351036071777, zero_point=0)
#         (bn1): Identity()
#         (conv2): QuantizedConvReLU2d(1024, 1024, kernel_size=(3, 3), stride=(1, 1), scale=24.671796798706055, zero_point=0, padding=(1, 1), groups=64)
#         (bn2): Identity()
#         (conv3): QuantizedConv2d(1024, 1024, kernel_size=(1, 1), stride=(1, 1), scale=42.51234436035156, zero_point=67)
#         (bn3): Identity()
#         (relu): ReLU()
#         (skip_add_relu): QFunctional(
#           scale=172.0297393798828, zero_point=0
#           (activation_post_process): Identity()
#         )
#         (relu1): Identity()
#         (relu2): Identity()
#       )
#       (14): QuantizableBottleneck(
#         (conv1): QuantizedConvReLU2d(1024, 1024, kernel_size=(1, 1), stride=(1, 1), scale=12.516609191894531, zero_point=0)
#         (bn1): Identity()
#         (conv2): QuantizedConvReLU2d(1024, 1024, kernel_size=(3, 3), stride=(1, 1), scale=18.744722366333008, zero_point=0, padding=(1, 1), groups=64)
#         (bn2): Identity()
#         (conv3): QuantizedConv2d(1024, 1024, kernel_size=(1, 1), stride=(1, 1), scale=36.48799514770508, zero_point=78)
#         (bn3): Identity()
#         (relu): ReLU()
#         (skip_add_relu): QFunctional(
#           scale=173.122314453125, zero_point=0
#           (activation_post_process): Identity()
#         )
#         (relu1): Identity()
#         (relu2): Identity()
#       )
#       (15): QuantizableBottleneck(
#         (conv1): QuantizedConvReLU2d(1024, 1024, kernel_size=(1, 1), stride=(1, 1), scale=9.95949649810791, zero_point=0)
#         (bn1): Identity()
#         (conv2): QuantizedConvReLU2d(1024, 1024, kernel_size=(3, 3), stride=(1, 1), scale=16.789836883544922, zero_point=0, padding=(1, 1), groups=64)
#         (bn2): Identity()
#         (conv3): QuantizedConv2d(1024, 1024, kernel_size=(1, 1), stride=(1, 1), scale=31.773588180541992, zero_point=67)
#         (bn3): Identity()
#         (relu): ReLU()
#         (skip_add_relu): QFunctional(
#           scale=173.36154174804688, zero_point=0
#           (activation_post_process): Identity()
#         )
#         (relu1): Identity()
#         (relu2): Identity()
#       )
#       (16): QuantizableBottleneck(
#         (conv1): QuantizedConvReLU2d(1024, 1024, kernel_size=(1, 1), stride=(1, 1), scale=6.358070373535156, zero_point=0)
#         (bn1): Identity()
#         (conv2): QuantizedConvReLU2d(1024, 1024, kernel_size=(3, 3), stride=(1, 1), scale=15.471461296081543, zero_point=0, padding=(1, 1), groups=64)
#         (bn2): Identity()
#         (conv3): QuantizedConv2d(1024, 1024, kernel_size=(1, 1), stride=(1, 1), scale=42.74467468261719, zero_point=84)
#         (bn3): Identity()
#         (relu): ReLU()
#         (skip_add_relu): QFunctional(
#           scale=172.36227416992188, zero_point=0
#           (activation_post_process): Identity()
#         )
#         (relu1): Identity()
#         (relu2): Identity()
#       )
#       (17): QuantizableBottleneck(
#         (conv1): QuantizedConvReLU2d(1024, 1024, kernel_size=(1, 1), stride=(1, 1), scale=11.183585166931152, zero_point=0)
#         (bn1): Identity()
#         (conv2): QuantizedConvReLU2d(1024, 1024, kernel_size=(3, 3), stride=(1, 1), scale=16.176830291748047, zero_point=0, padding=(1, 1), groups=64)
#         (bn2): Identity()
#         (conv3): QuantizedConv2d(1024, 1024, kernel_size=(1, 1), stride=(1, 1), scale=50.54222106933594, zero_point=64)
#         (bn3): Identity()
#         (relu): ReLU()
#         (skip_add_relu): QFunctional(
#           scale=180.7364044189453, zero_point=0
#           (activation_post_process): Identity()
#         )
#         (relu1): Identity()
#         (relu2): Identity()
#       )
#       (18): QuantizableBottleneck(
#         (conv1): QuantizedConvReLU2d(1024, 1024, kernel_size=(1, 1), stride=(1, 1), scale=7.764074325561523, zero_point=0)
#         (bn1): Identity()
#         (conv2): QuantizedConvReLU2d(1024, 1024, kernel_size=(3, 3), stride=(1, 1), scale=24.134233474731445, zero_point=0, padding=(1, 1), groups=64)
#         (bn2): Identity()
#         (conv3): QuantizedConv2d(1024, 1024, kernel_size=(1, 1), stride=(1, 1), scale=53.246177673339844, zero_point=80)
#         (bn3): Identity()
#         (relu): ReLU()
#         (skip_add_relu): QFunctional(
#           scale=187.67669677734375, zero_point=0
#           (activation_post_process): Identity()
#         )
#         (relu1): Identity()
#         (relu2): Identity()
#       )
#       (19): QuantizableBottleneck(
#         (conv1): QuantizedConvReLU2d(1024, 1024, kernel_size=(1, 1), stride=(1, 1), scale=13.648157119750977, zero_point=0)
#         (bn1): Identity()
#         (conv2): QuantizedConvReLU2d(1024, 1024, kernel_size=(3, 3), stride=(1, 1), scale=24.698606491088867, zero_point=0, padding=(1, 1), groups=64)
#         (bn2): Identity()
#         (conv3): QuantizedConv2d(1024, 1024, kernel_size=(1, 1), stride=(1, 1), scale=97.85851287841797, zero_point=40)
#         (bn3): Identity()
#         (relu): ReLU()
#         (skip_add_relu): QFunctional(
#           scale=189.24195861816406, zero_point=0
#           (activation_post_process): Identity()
#         )
#         (relu1): Identity()
#         (relu2): Identity()
#       )
#       (20): QuantizableBottleneck(
#         (conv1): QuantizedConvReLU2d(1024, 1024, kernel_size=(1, 1), stride=(1, 1), scale=23.334957122802734, zero_point=0)
#         (bn1): Identity()
#         (conv2): QuantizedConvReLU2d(1024, 1024, kernel_size=(3, 3), stride=(1, 1), scale=67.47544860839844, zero_point=0, padding=(1, 1), groups=64)
#         (bn2): Identity()
#         (conv3): QuantizedConv2d(1024, 1024, kernel_size=(1, 1), stride=(1, 1), scale=211.8326873779297, zero_point=56)
#         (bn3): Identity()
#         (relu): ReLU()
#         (skip_add_relu): QFunctional(
#           scale=157.00311279296875, zero_point=0
#           (activation_post_process): Identity()
#         )
#         (relu1): Identity()
#         (relu2): Identity()
#       )
#       (21): QuantizableBottleneck(
#         (conv1): QuantizedConvReLU2d(1024, 1024, kernel_size=(1, 1), stride=(1, 1), scale=31.92168426513672, zero_point=0)
#         (bn1): Identity()
#         (conv2): QuantizedConvReLU2d(1024, 1024, kernel_size=(3, 3), stride=(1, 1), scale=71.90938568115234, zero_point=0, padding=(1, 1), groups=64)
#         (bn2): Identity()
#         (conv3): QuantizedConv2d(1024, 1024, kernel_size=(1, 1), stride=(1, 1), scale=336.5284729003906, zero_point=116)
#         (bn3): Identity()
#         (relu): ReLU()
#         (skip_add_relu): QFunctional(
#           scale=112.91535949707031, zero_point=0
#           (activation_post_process): Identity()
#         )
#         (relu1): Identity()
#         (relu2): Identity()
#       )
#       (22): QuantizableBottleneck(
#         (conv1): QuantizedConvReLU2d(1024, 1024, kernel_size=(1, 1), stride=(1, 1), scale=29.438941955566406, zero_point=0)
#         (bn1): Identity()
#         (conv2): QuantizedConvReLU2d(1024, 1024, kernel_size=(3, 3), stride=(1, 1), scale=49.124961853027344, zero_point=0, padding=(1, 1), groups=64)
#         (bn2): Identity()
#         (conv3): QuantizedConv2d(1024, 1024, kernel_size=(1, 1), stride=(1, 1), scale=158.88197326660156, zero_point=107)
#         (bn3): Identity()
#         (relu): ReLU()
#         (skip_add_relu): QFunctional(
#           scale=76.41522979736328, zero_point=0
#           (activation_post_process): Identity()
#         )
#         (relu1): Identity()
#         (relu2): Identity()
#       )
#     )
#     (layer4): Sequential(
#       (0): QuantizableBottleneck(
#         (conv1): QuantizedConvReLU2d(1024, 2048, kernel_size=(1, 1), stride=(1, 1), scale=6.016822338104248, zero_point=0)
#         (bn1): Identity()
#         (conv2): QuantizedConvReLU2d(2048, 2048, kernel_size=(3, 3), stride=(2, 2), scale=43.463504791259766, zero_point=0, padding=(1, 1), groups=64)
#         (bn2): Identity()
#         (conv3): QuantizedConv2d(2048, 2048, kernel_size=(1, 1), stride=(1, 1), scale=85.8796615600586, zero_point=71)
#         (bn3): Identity()
#         (relu): ReLU()
#         (downsample): Sequential(
#           (0): QuantizedConv2d(1024, 2048, kernel_size=(1, 1), stride=(2, 2), scale=38.85759735107422, zero_point=74)
#           (1): Identity()
#         )
#         (skip_add_relu): QFunctional(
#           scale=43.20756149291992, zero_point=0
#           (activation_post_process): Identity()
#         )
#         (relu1): Identity()
#         (relu2): Identity()
#       )
#       (1): QuantizableBottleneck(
#         (conv1): QuantizedConvReLU2d(2048, 2048, kernel_size=(1, 1), stride=(1, 1), scale=13.881043434143066, zero_point=0)
#         (bn1): Identity()
#         (conv2): QuantizedConvReLU2d(2048, 2048, kernel_size=(3, 3), stride=(1, 1), scale=16.862289428710938, zero_point=0, padding=(1, 1), groups=64)
#         (bn2): Identity()
#         (conv3): QuantizedConv2d(2048, 2048, kernel_size=(1, 1), stride=(1, 1), scale=74.20989990234375, zero_point=76)
#         (bn3): Identity()
#         (relu): ReLU()
#         (skip_add_relu): QFunctional(
#           scale=40.426612854003906, zero_point=0
#           (activation_post_process): Identity()
#         )
#         (relu1): Identity()
#         (relu2): Identity()
#       )
#       (2): QuantizableBottleneck(
#         (conv1): QuantizedConvReLU2d(2048, 2048, kernel_size=(1, 1), stride=(1, 1), scale=18.158737182617188, zero_point=0)
#         (bn1): Identity()
#         (conv2): QuantizedConvReLU2d(2048, 2048, kernel_size=(3, 3), stride=(1, 1), scale=32.31345748901367, zero_point=0, padding=(1, 1), groups=64)
#         (bn2): Identity()
#         (conv3): QuantizedConv2d(2048, 2048, kernel_size=(1, 1), stride=(1, 1), scale=130.18923950195312, zero_point=88)
#         (bn3): Identity()
#         (relu): ReLU()
#         (skip_add_relu): QFunctional(
#           scale=53.656551361083984, zero_point=0
#           (activation_post_process): Identity()
#         )
#         (relu1): Identity()
#         (relu2): Identity()
#       )
#     )
#     (avgpool): AdaptiveAvgPool2d(output_size=(1, 1))
#     (fc): QuantizedLinear(in_features=2048, out_features=1280, scale=4.475791931152344, zero_point=57, qscheme=torch.per_channel_affine)
#     (quant): Quantize(scale=tensor([8.1437]), zero_point=tensor([0]), dtype=torch.quint8)
#     (dequant): DeQuantize()
#   )
#   (1): G0: (0.000024, 0.820293), G1: (-0.000113, 0.796738), G2: (-0.000099, 0.791270)
#   (2): QuantWrapper(
#     (quant): Quantize(scale=tensor([47.8090]), zero_point=tensor([49]), dtype=torch.quint8)
#     (dequant): DeQuantize()
#     (module): QuantizedLinear(in_features=1280, out_features=1, scale=25.568452835083008, zero_point=126, qscheme=torch.per_channel_affine)
#   )
# )

# %%
test_loss, test_acc, test_auc, tst_preds, tst_gts, tst_attrs, tst_pred_gt_by_attrs, tst_other_metrics = validation(qmodel, criterion, optimizer, validation_dataset_loader, epoch, identity_Info=imb_info, _device='cpu')
# Out:
# cpu
# test <==== epcoh 4 loss: 7.3356 auc: 0.4951
# 0-attr auc: 0.4965
# 1-attr auc: 0.5019
# 2-attr auc: 0.4871

# %%
forward_model_with_fin(qmodel, i[0], i[2]), i[1]
# Out:
# ((tensor([[0.],
#           [0.],
#           [0.],
#           [0.],
#           [0.],
#           [0.]]),
#   tensor([[-0.0056,  0.0104, -0.0095,  ..., -0.0075,  0.0050, -0.0149],
#           [-0.0056,  0.0104, -0.0095,  ..., -0.0075,  0.0050, -0.0149],
#           [ 0.0029, -0.0043,  0.0092,  ..., -0.0040,  0.0090,  0.0016],
#           [-0.0056,  0.0104, -0.0095,  ..., -0.0075,  0.0050, -0.0149],
#           [-0.0056,  0.0104, -0.0095,  ..., -0.0075,  0.0050, -0.0149],
#           [-0.0040, -0.0076,  0.0070,  ...,  0.0041,  0.0212,  0.0049]],
#          grad_fn=<CopySlices>)),
#  tensor([0., 1., 0., 1., 0., 1.]))

# %%
forward_model_with_fin(model.to('cpu'), i[0], i[2]), i[1]
# Out:
# ((tensor([[ -6.7776],
#           [ 10.7342],
#           [-14.3578],
#           [ 18.2717],
#           [ -6.4111],
#           [  6.9140]], grad_fn=<MmBackward0>),
#   tensor([[-0.1255, -0.4943,  0.9652,  ...,  0.2935, -0.2616, -0.2475],
#           [ 0.2636,  1.0062, -1.7994,  ..., -0.3134,  0.2436,  0.4206],
#           [-0.4610, -0.4019,  1.4701,  ...,  0.6462, -2.1826, -0.4101],
#           [ 0.2795,  1.5579, -3.1290,  ..., -0.3701,  0.1406,  0.7438],
#           [-0.1650, -0.4156,  1.4783,  ...,  0.0969, -0.3455, -0.1474],
#           [ 0.3351,  0.2130, -0.3723,  ..., -0.3091, -0.0670,  0.2366]],
#          grad_fn=<CopySlices>)),
#  tensor([0., 1., 0., 1., 0., 1.]))
