# %%
import os
import argparse
import random
import time
import json

import numpy as np
import torch
import torch.nn as nn
from torch.optim.lr_scheduler import *
from torch.optim import *
import torch.nn.functional as F

from sklearn.metrics import *
from sklearn.model_selection import KFold

import sys
sys.path.append('.')

from src.modules import *
from src.data_handler import *
from src import logger
from src.class_balanced_loss import *
from typing import NamedTuple
from torchvision.models import efficientnet as efn

from train_glaucoma_fair_fin import train, validation, Identity_Info, quantifiable_efficientnet

from fairlearn.metrics import *

imb_info = Identity_Info()

# %%
out_dim = 1
criterion = nn.BCEWithLogitsLoss()
predictor_head = nn.Sigmoid()
in_feat_to_final = 1280
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

fin_mu = 0.01
fin_sigma = 1.
fin_momentum = 0.3
model_type = 'quant'# 'resnext'  # or quant
modality_types = 'rnflt'
task = 'cls'
pretrained_weights = 'results/crosssectional_rnflt_fin_race_ablation_of_sigma/fullysup_quant_rnflt_Taskcls_lr5e-5_bz6_4442_auc0.7311/best_weights.pth'
pretrained_weights = 'results/crosssectional_rnflt_fin_race_ablation_of_sigma/fullysup_resnext_rnflt_Taskcls_lr5e-5_bz6_3162_auc0.8324/best_weights.pth'
if model_type == 'resnext':
    pretrained_weights = 'results/crosssectional_rnflt_fin_race_ablation_of_sigma/fullysup_resnext_rnflt_Taskcls_lr5e-5_bz6_865_auc0.8510/last_weights.pth'
else:
    pretrained_weights = 'results/crosssectional_rnflt_fin_race_ablation_of_sigma/fullysup_quant_rnflt_Taskcls_lr5e-5_bz6_9354_auc0.8495/best_weights.pth'

ag_norm = Fair_Identity_Normalizer(
    3,
    dim=in_feat_to_final,
    mu=fin_mu,
    sigma=fin_sigma,
    momentum=fin_momentum,
)
in_dim = 1
# model = quantifiable_efficientnet(width_mult=1.0, depth_mult=1.0, weights=EfficientNet_B1_Weights.IMAGENET1K_V2)# create_model(model_type=model_type, in_dim=in_dim, out_dim=out_dim, include_final=False)
model = create_model(model_type=model_type, in_dim=in_dim, out_dim=out_dim, include_final=False)
final_layer = nn.Linear(in_features=in_feat_to_final, out_features=out_dim, bias=False)
model = nn.Sequential(model, ag_norm, final_layer)
model = model.to(device)

checkpoint = torch.load(pretrained_weights)

start_epoch = checkpoint['epoch'] + 1
model.load_state_dict(checkpoint['model_state_dict'])
# efnm = create_model(model_type=model_type, in_dim=in_dim, out_dim=out_dim, include_final=False)
# optimizer.load_state_dict(checkpoint['optimizer_state_dict'])
# scaler.load_state_dict(checkpoint['scaler_state_dict'])
# scheduler.load_state_dict(checkpoint['scheduler_state_dict'])
# Out:
# <All keys matched successfully>

# %%
data_dir = "../quant_notes/data_cmpr"
image_size = 200
attribute_type = "race"

trn_dataset = EyeFair(
    os.path.join(data_dir, "train"),
    modality_type=modality_types,
    task=task,
    resolution=image_size,
    attribute_type=attribute_type,
    depth=3 if model_type == "resnext" else 1,
)
tst_dataset = EyeFair(
    os.path.join(data_dir, "test"),
    modality_type=modality_types,
    task=task,
    resolution=image_size,
    attribute_type=attribute_type,
    depth=3 if model_type == "resnext" else 1,
)

batch_size = 6
workers = 1

train_dataset_loader = torch.utils.data.DataLoader(
    trn_dataset,
    batch_size=batch_size,
    shuffle=True,
    num_workers=workers,
    pin_memory=True,
    drop_last=True,
)

validation_dataset_loader = torch.utils.data.DataLoader(
    tst_dataset,
    batch_size=batch_size,
    shuffle=False,
    num_workers=workers,
    pin_memory=True,
    drop_last=False,
)
# Out:
# min: -31.9900, max: 2.2700
# min: -31.1600, max: 2.5300

# %%
for i in train_dataset_loader:
    print(i[0].dtype)
    break
# Out:
# torch.float32

# %%
from copy import deepcopy

import torch.ao.quantization
qmodel = deepcopy(model).to('cpu')
if model_type == 'resnext':
    qmodel[0].fuse_model(is_qat=True)
else:
    qmodel[0] = torch.quantization.QuantWrapper(qmodel[0])
qmodel[1].v = False
# qmodel = torch.ao.quantization.fuse_modules(model, ['conv2', 'bn2'])
qmodel[2] = torch.quantization.QuantWrapper(qmodel[2])
qmodel.qconfig = torch.ao.quantization.default_per_channel_qconfig
torch.ao.quantization.prepare_qat(qmodel, inplace=True)
print(qmodel.qconfig)
# Out:
# QConfig(activation=functools.partial(<class 'torch.ao.quantization.observer.MinMaxObserver'>, quant_min=0, quant_max=127){'factory_kwargs': <function _add_module_to_qconfig_obs_ctr.<locals>.get_factory_kwargs_based_on_module_device at 0x7fba753416c0>}, weight=functools.partial(<class 'torch.ao.quantization.observer.PerChannelMinMaxObserver'>, dtype=torch.qint8, qscheme=torch.per_channel_symmetric){'factory_kwargs': <function _add_module_to_qconfig_obs_ctr.<locals>.get_factory_kwargs_based_on_module_device at 0x7fba753416c0>})

# %%
# scaler = torch.cuda.amp.GradScaler()
scaler = None

optimizer = AdamW(qmodel.parameters(), lr=5e-5, betas=(0.0, 0.1), weight_decay=0.)

scheduler = StepLR(optimizer, step_size=30, gamma=0.1)

for epoch in range(start_epoch, start_epoch+4):
    train_loss, train_acc, train_auc, trn_preds, trn_gts, trn_attrs, trn_pred_gt_by_attrs, trn_other_metrics = train(qmodel, criterion, optimizer, scaler, train_dataset_loader, epoch, None, identity_Info=imb_info, time_window=-1, _device='cpu')
    test_loss, test_acc, test_auc, tst_preds, tst_gts, tst_attrs, tst_pred_gt_by_attrs, tst_other_metrics = validation(qmodel, criterion, optimizer, validation_dataset_loader, epoch, identity_Info=imb_info, _device='cpu')
    scheduler.step()
# Out:
# 349train ====> epcoh 2 loss: 0.5350 auc: 0.8055 time: 282.7320
# 0-attr auc: 0.8228
# 1-attr auc: 0.7849
# 2-attr auc: 0.7869
# cpu
# test <==== epcoh 2 loss: 3.0521 auc: 0.8398
# 0-attr auc: 0.8567
# 1-attr auc: 0.7945
# 2-attr auc: 0.8513
# 349train ====> epcoh 3 loss: 0.5122 auc: 0.8210 time: 288.8274
# 0-attr auc: 0.8354
# 1-attr auc: 0.8068
# 2-attr auc: 0.8046
# cpu
# test <==== epcoh 3 loss: 1.5259 auc: 0.8378
# 0-attr auc: 0.8442
# 1-attr auc: 0.7906
# 2-attr auc: 0.8543
# 349train ====> epcoh 4 loss: 0.4939 auc: 0.8372 time: 274.7201
# 0-attr auc: 0.8433
# 1-attr auc: 0.8465
# 2-attr auc: 0.8073
# cpu
# test <==== epcoh 4 loss: 4.1779 auc: 0.8296
# 0-attr auc: 0.8368
# 1-attr auc: 0.7934
# 2-attr auc: 0.8346
# 349train ====> epcoh 5 loss: 0.4710 auc: 0.8503 time: 272.4942
# 0-attr auc: 0.8549
# 1-attr auc: 0.8307
# 2-attr auc: 0.8505
# cpu
# test <==== epcoh 5 loss: 12.2015 auc: 0.8322
# 0-attr auc: 0.8356
# 1-attr auc: 0.7890
# 2-attr auc: 0.8544

# %%
qmodel.eval()
torch.quantization.convert(qmodel, inplace=True)
# Out:
# /home/pcsmet/miniconda3/envs/harvard_gf/lib/python3.10/site-packages/torch/ao/quantization/utils.py:339: UserWarning: must run observer before calling calculate_qparams. Returning default values.
#   warnings.warn(
# Sequential(
#   (0): QuantWrapper(
#     (quant): Quantize(scale=tensor([8.1437]), zero_point=tensor([0]), dtype=torch.quint8)
#     (dequant): DeQuantize()
#     (module): EfficientNet(
#       (features): Sequential(
#         (0): Conv2dNormActivation(
#           (0): QuantizedConv2d(1, 32, kernel_size=(3, 3), stride=(2, 2), scale=17.555675506591797, zero_point=51, padding=(1, 1), bias=False)
#           (1): QuantizedBatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): QuantizedHardswish()
#         )
#         (1): Sequential(
#           (0): QuantizableMBConv(
#             (block): Sequential(
#               (0): Conv2dNormActivation(
#                 (0): QuantizedConv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), scale=17.564468383789062, zero_point=53, padding=(1, 1), groups=32, bias=False)
#                 (1): QuantizedBatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                 (2): QuantizedHardswish()
#               )
#               (1): QuantizableSqueezeExcitation(
#                 (avgpool): AdaptiveAvgPool2d(output_size=1)
#                 (fc1): QuantizedConv2d(32, 8, kernel_size=(1, 1), stride=(1, 1), scale=0.4169282019138336, zero_point=126)
#                 (fc2): QuantizedConv2d(8, 32, kernel_size=(1, 1), stride=(1, 1), scale=0.05391894280910492, zero_point=98)
#                 (activation): QuantizedHardswish()
#                 (scale_activation): Hardsigmoid()
#                 (skip_mul): QFunctional(
#                   scale=4.490659713745117, zero_point=0
#                   (activation_post_process): Identity()
#                 )
#               )
#               (2): Conv2dNormActivation(
#                 (0): QuantizedConv2d(32, 16, kernel_size=(1, 1), stride=(1, 1), scale=12.556962966918945, zero_point=77, bias=False)
#                 (1): QuantizedBatchNorm2d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               )
#             )
#             (stochastic_depth): StochasticDepth(p=0.0, mode=row)
#             (f_add): QFunctional(
#               scale=1.0, zero_point=0
#               (activation_post_process): Identity()
#             )
#           )
#           (1): QuantizableMBConv(
#             (block): Sequential(
#               (0): Conv2dNormActivation(
#                 (0): QuantizedConv2d(16, 16, kernel_size=(3, 3), stride=(1, 1), scale=76.99430847167969, zero_point=85, padding=(1, 1), groups=16, bias=False)
#                 (1): QuantizedBatchNorm2d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                 (2): QuantizedHardswish()
#               )
#               (1): QuantizableSqueezeExcitation(
#                 (avgpool): AdaptiveAvgPool2d(output_size=1)
#                 (fc1): QuantizedConv2d(16, 4, kernel_size=(1, 1), stride=(1, 1), scale=0.1307162046432495, zero_point=126)
#                 (fc2): QuantizedConv2d(4, 16, kernel_size=(1, 1), stride=(1, 1), scale=0.03138337284326553, zero_point=103)
#                 (activation): QuantizedHardswish()
#                 (scale_activation): Hardsigmoid()
#                 (skip_mul): QFunctional(
#                   scale=1.346380352973938, zero_point=0
#                   (activation_post_process): Identity()
#                 )
#               )
#               (2): Conv2dNormActivation(
#                 (0): QuantizedConv2d(16, 16, kernel_size=(1, 1), stride=(1, 1), scale=4.083521366119385, zero_point=68, bias=False)
#                 (1): QuantizedBatchNorm2d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               )
#             )
#             (stochastic_depth): StochasticDepth(p=0.008695652173913044, mode=row)
#             (f_add): QFunctional(
#               scale=40.11546325683594, zero_point=59
#               (activation_post_process): Identity()
#             )
#           )
#         )
#         (2): Sequential(
#           (0): QuantizableMBConv(
#             (block): Sequential(
#               (0): Conv2dNormActivation(
#                 (0): QuantizedConv2d(16, 96, kernel_size=(1, 1), stride=(1, 1), scale=162.0957794189453, zero_point=60, bias=False)
#                 (1): QuantizedBatchNorm2d(96, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                 (2): QuantizedHardswish()
#               )
#               (1): Conv2dNormActivation(
#                 (0): QuantizedConv2d(96, 96, kernel_size=(3, 3), stride=(2, 2), scale=104.05924224853516, zero_point=72, padding=(1, 1), groups=96, bias=False)
#                 (1): QuantizedBatchNorm2d(96, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                 (2): QuantizedHardswish()
#               )
#               (2): QuantizableSqueezeExcitation(
#                 (avgpool): AdaptiveAvgPool2d(output_size=1)
#                 (fc1): QuantizedConv2d(96, 4, kernel_size=(1, 1), stride=(1, 1), scale=0.1345604509115219, zero_point=127)
#                 (fc2): QuantizedConv2d(4, 96, kernel_size=(1, 1), stride=(1, 1), scale=0.02613385207951069, zero_point=59)
#                 (activation): QuantizedHardswish()
#                 (scale_activation): Hardsigmoid()
#                 (skip_mul): QFunctional(
#                   scale=7.0938873291015625, zero_point=0
#                   (activation_post_process): Identity()
#                 )
#               )
#               (3): Conv2dNormActivation(
#                 (0): QuantizedConv2d(96, 24, kernel_size=(1, 1), stride=(1, 1), scale=33.406497955322266, zero_point=79, bias=False)
#                 (1): QuantizedBatchNorm2d(24, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               )
#             )
#             (stochastic_depth): StochasticDepth(p=0.017391304347826087, mode=row)
#             (f_add): QFunctional(
#               scale=1.0, zero_point=0
#               (activation_post_process): Identity()
#             )
#           )
#           (1): QuantizableMBConv(
#             (block): Sequential(
#               (0): Conv2dNormActivation(
#                 (0): QuantizedConv2d(24, 144, kernel_size=(1, 1), stride=(1, 1), scale=98.43112182617188, zero_point=73, bias=False)
#                 (1): QuantizedBatchNorm2d(144, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                 (2): QuantizedHardswish()
#               )
#               (1): Conv2dNormActivation(
#                 (0): QuantizedConv2d(144, 144, kernel_size=(3, 3), stride=(1, 1), scale=12.332719802856445, zero_point=69, padding=(1, 1), groups=144, bias=False)
#                 (1): QuantizedBatchNorm2d(144, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                 (2): QuantizedHardswish()
#               )
#               (2): QuantizableSqueezeExcitation(
#                 (avgpool): AdaptiveAvgPool2d(output_size=1)
#                 (fc1): QuantizedConv2d(144, 6, kernel_size=(1, 1), stride=(1, 1), scale=0.300037145614624, zero_point=127)
#                 (fc2): QuantizedConv2d(6, 144, kernel_size=(1, 1), stride=(1, 1), scale=0.027898181229829788, zero_point=81)
#                 (activation): QuantizedHardswish()
#                 (scale_activation): Hardsigmoid()
#                 (skip_mul): QFunctional(
#                   scale=2.964258909225464, zero_point=0
#                   (activation_post_process): Identity()
#                 )
#               )
#               (3): Conv2dNormActivation(
#                 (0): QuantizedConv2d(144, 24, kernel_size=(1, 1), stride=(1, 1), scale=9.754207611083984, zero_point=56, bias=False)
#                 (1): QuantizedBatchNorm2d(24, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               )
#             )
#             (stochastic_depth): StochasticDepth(p=0.026086956521739136, mode=row)
#             (f_add): QFunctional(
#               scale=25.4127254486084, zero_point=76
#               (activation_post_process): Identity()
#             )
#           )
#           (2): QuantizableMBConv(
#             (block): Sequential(
#               (0): Conv2dNormActivation(
#                 (0): QuantizedConv2d(24, 144, kernel_size=(1, 1), stride=(1, 1), scale=71.56171417236328, zero_point=65, bias=False)
#                 (1): QuantizedBatchNorm2d(144, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                 (2): QuantizedHardswish()
#               )
#               (1): Conv2dNormActivation(
#                 (0): QuantizedConv2d(144, 144, kernel_size=(3, 3), stride=(1, 1), scale=9.522167205810547, zero_point=82, padding=(1, 1), groups=144, bias=False)
#                 (1): QuantizedBatchNorm2d(144, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                 (2): QuantizedHardswish()
#               )
#               (2): QuantizableSqueezeExcitation(
#                 (avgpool): AdaptiveAvgPool2d(output_size=1)
#                 (fc1): QuantizedConv2d(144, 6, kernel_size=(1, 1), stride=(1, 1), scale=0.21053342521190643, zero_point=102)
#                 (fc2): QuantizedConv2d(6, 144, kernel_size=(1, 1), stride=(1, 1), scale=0.1320280283689499, zero_point=56)
#                 (activation): QuantizedHardswish()
#                 (scale_activation): Hardsigmoid()
#                 (skip_mul): QFunctional(
#                   scale=8.085040092468262, zero_point=0
#                   (activation_post_process): Identity()
#                 )
#               )
#               (3): Conv2dNormActivation(
#                 (0): QuantizedConv2d(144, 24, kernel_size=(1, 1), stride=(1, 1), scale=14.73215103149414, zero_point=57, bias=False)
#                 (1): QuantizedBatchNorm2d(24, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               )
#             )
#             (stochastic_depth): StochasticDepth(p=0.034782608695652174, mode=row)
#             (f_add): QFunctional(
#               scale=43.64533233642578, zero_point=74
#               (activation_post_process): Identity()
#             )
#           )
#         )
#         (3): Sequential(
#           (0): QuantizableMBConv(
#             (block): Sequential(
#               (0): Conv2dNormActivation(
#                 (0): QuantizedConv2d(24, 144, kernel_size=(1, 1), stride=(1, 1), scale=214.83966064453125, zero_point=80, bias=False)
#                 (1): QuantizedBatchNorm2d(144, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                 (2): QuantizedHardswish()
#               )
#               (1): Conv2dNormActivation(
#                 (0): QuantizedConv2d(144, 144, kernel_size=(5, 5), stride=(2, 2), scale=13.054449081420898, zero_point=81, padding=(2, 2), groups=144, bias=False)
#                 (1): QuantizedBatchNorm2d(144, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                 (2): QuantizedHardswish()
#               )
#               (2): QuantizableSqueezeExcitation(
#                 (avgpool): AdaptiveAvgPool2d(output_size=1)
#                 (fc1): QuantizedConv2d(144, 6, kernel_size=(1, 1), stride=(1, 1), scale=0.27273210883140564, zero_point=127)
#                 (fc2): QuantizedConv2d(6, 144, kernel_size=(1, 1), stride=(1, 1), scale=0.026934277266263962, zero_point=67)
#                 (activation): QuantizedHardswish()
#                 (scale_activation): Hardsigmoid()
#                 (skip_mul): QFunctional(
#                   scale=1.3999110460281372, zero_point=0
#                   (activation_post_process): Identity()
#                 )
#               )
#               (3): Conv2dNormActivation(
#                 (0): QuantizedConv2d(144, 40, kernel_size=(1, 1), stride=(1, 1), scale=5.737974643707275, zero_point=70, bias=False)
#                 (1): QuantizedBatchNorm2d(40, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               )
#             )
#             (stochastic_depth): StochasticDepth(p=0.043478260869565216, mode=row)
#             (f_add): QFunctional(
#               scale=1.0, zero_point=0
#               (activation_post_process): Identity()
#             )
#           )
#           (1): QuantizableMBConv(
#             (block): Sequential(
#               (0): Conv2dNormActivation(
#                 (0): QuantizedConv2d(40, 240, kernel_size=(1, 1), stride=(1, 1), scale=53.02546691894531, zero_point=50, bias=False)
#                 (1): QuantizedBatchNorm2d(240, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                 (2): QuantizedHardswish()
#               )
#               (1): Conv2dNormActivation(
#                 (0): QuantizedConv2d(240, 240, kernel_size=(5, 5), stride=(1, 1), scale=28.2036075592041, zero_point=118, padding=(2, 2), groups=240, bias=False)
#                 (1): QuantizedBatchNorm2d(240, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                 (2): QuantizedHardswish()
#               )
#               (2): QuantizableSqueezeExcitation(
#                 (avgpool): AdaptiveAvgPool2d(output_size=1)
#                 (fc1): QuantizedConv2d(240, 10, kernel_size=(1, 1), stride=(1, 1), scale=0.1412489414215088, zero_point=97)
#                 (fc2): QuantizedConv2d(10, 240, kernel_size=(1, 1), stride=(1, 1), scale=0.15994393825531006, zero_point=94)
#                 (activation): QuantizedHardswish()
#                 (scale_activation): Hardsigmoid()
#                 (skip_mul): QFunctional(
#                   scale=12.581231117248535, zero_point=0
#                   (activation_post_process): Identity()
#                 )
#               )
#               (3): Conv2dNormActivation(
#                 (0): QuantizedConv2d(240, 40, kernel_size=(1, 1), stride=(1, 1), scale=17.41457748413086, zero_point=62, bias=False)
#                 (1): QuantizedBatchNorm2d(40, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               )
#             )
#             (stochastic_depth): StochasticDepth(p=0.05217391304347827, mode=row)
#             (f_add): QFunctional(
#               scale=37.432647705078125, zero_point=51
#               (activation_post_process): Identity()
#             )
#           )
#           (2): QuantizableMBConv(
#             (block): Sequential(
#               (0): Conv2dNormActivation(
#                 (0): QuantizedConv2d(40, 240, kernel_size=(1, 1), stride=(1, 1), scale=94.73344421386719, zero_point=70, bias=False)
#                 (1): QuantizedBatchNorm2d(240, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                 (2): QuantizedHardswish()
#               )
#               (1): Conv2dNormActivation(
#                 (0): QuantizedConv2d(240, 240, kernel_size=(5, 5), stride=(1, 1), scale=16.56069564819336, zero_point=63, padding=(2, 2), groups=240, bias=False)
#                 (1): QuantizedBatchNorm2d(240, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                 (2): QuantizedHardswish()
#               )
#               (2): QuantizableSqueezeExcitation(
#                 (avgpool): AdaptiveAvgPool2d(output_size=1)
#                 (fc1): QuantizedConv2d(240, 10, kernel_size=(1, 1), stride=(1, 1), scale=0.7088592648506165, zero_point=102)
#                 (fc2): QuantizedConv2d(10, 240, kernel_size=(1, 1), stride=(1, 1), scale=0.25622665882110596, zero_point=70)
#                 (activation): QuantizedHardswish()
#                 (scale_activation): Hardsigmoid()
#                 (skip_mul): QFunctional(
#                   scale=4.950880527496338, zero_point=0
#                   (activation_post_process): Identity()
#                 )
#               )
#               (3): Conv2dNormActivation(
#                 (0): QuantizedConv2d(240, 40, kernel_size=(1, 1), stride=(1, 1), scale=15.25060749053955, zero_point=79, bias=False)
#                 (1): QuantizedBatchNorm2d(40, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               )
#             )
#             (stochastic_depth): StochasticDepth(p=0.06086956521739131, mode=row)
#             (f_add): QFunctional(
#               scale=36.047950744628906, zero_point=50
#               (activation_post_process): Identity()
#             )
#           )
#         )
#         (4): Sequential(
#           (0): QuantizableMBConv(
#             (block): Sequential(
#               (0): Conv2dNormActivation(
#                 (0): QuantizedConv2d(40, 240, kernel_size=(1, 1), stride=(1, 1), scale=116.9051742553711, zero_point=77, bias=False)
#                 (1): QuantizedBatchNorm2d(240, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                 (2): QuantizedHardswish()
#               )
#               (1): Conv2dNormActivation(
#                 (0): QuantizedConv2d(240, 240, kernel_size=(3, 3), stride=(2, 2), scale=9.101208686828613, zero_point=75, padding=(1, 1), groups=240, bias=False)
#                 (1): QuantizedBatchNorm2d(240, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                 (2): QuantizedHardswish()
#               )
#               (2): QuantizableSqueezeExcitation(
#                 (avgpool): AdaptiveAvgPool2d(output_size=1)
#                 (fc1): QuantizedConv2d(240, 10, kernel_size=(1, 1), stride=(1, 1), scale=0.17129704356193542, zero_point=121)
#                 (fc2): QuantizedConv2d(10, 240, kernel_size=(1, 1), stride=(1, 1), scale=0.01894865557551384, zero_point=56)
#                 (activation): QuantizedHardswish()
#                 (scale_activation): Hardsigmoid()
#                 (skip_mul): QFunctional(
#                   scale=8.814733505249023, zero_point=0
#                   (activation_post_process): Identity()
#                 )
#               )
#               (3): Conv2dNormActivation(
#                 (0): QuantizedConv2d(240, 80, kernel_size=(1, 1), stride=(1, 1), scale=7.9520745277404785, zero_point=71, bias=False)
#                 (1): QuantizedBatchNorm2d(80, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               )
#             )
#             (stochastic_depth): StochasticDepth(p=0.06956521739130435, mode=row)
#             (f_add): QFunctional(
#               scale=1.0, zero_point=0
#               (activation_post_process): Identity()
#             )
#           )
#           (1): QuantizableMBConv(
#             (block): Sequential(
#               (0): Conv2dNormActivation(
#                 (0): QuantizedConv2d(80, 480, kernel_size=(1, 1), stride=(1, 1), scale=52.43612289428711, zero_point=70, bias=False)
#                 (1): QuantizedBatchNorm2d(480, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                 (2): QuantizedHardswish()
#               )
#               (1): Conv2dNormActivation(
#                 (0): QuantizedConv2d(480, 480, kernel_size=(3, 3), stride=(1, 1), scale=7.897356986999512, zero_point=64, padding=(1, 1), groups=480, bias=False)
#                 (1): QuantizedBatchNorm2d(480, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                 (2): QuantizedHardswish()
#               )
#               (2): QuantizableSqueezeExcitation(
#                 (avgpool): AdaptiveAvgPool2d(output_size=1)
#                 (fc1): QuantizedConv2d(480, 20, kernel_size=(1, 1), stride=(1, 1), scale=2.301280975341797, zero_point=49)
#                 (fc2): QuantizedConv2d(20, 480, kernel_size=(1, 1), stride=(1, 1), scale=10.141918182373047, zero_point=21)
#                 (activation): QuantizedHardswish()
#                 (scale_activation): Hardsigmoid()
#                 (skip_mul): QFunctional(
#                   scale=68.34477996826172, zero_point=0
#                   (activation_post_process): Identity()
#                 )
#               )
#               (3): Conv2dNormActivation(
#                 (0): QuantizedConv2d(480, 80, kernel_size=(1, 1), stride=(1, 1), scale=119.40917205810547, zero_point=88, bias=False)
#                 (1): QuantizedBatchNorm2d(80, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               )
#             )
#             (stochastic_depth): StochasticDepth(p=0.0782608695652174, mode=row)
#             (f_add): QFunctional(
#               scale=640.5875854492188, zero_point=92
#               (activation_post_process): Identity()
#             )
#           )
#           (2): QuantizableMBConv(
#             (block): Sequential(
#               (0): Conv2dNormActivation(
#                 (0): QuantizedConv2d(80, 480, kernel_size=(1, 1), stride=(1, 1), scale=1343.0172119140625, zero_point=69, bias=False)
#                 (1): QuantizedBatchNorm2d(480, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                 (2): QuantizedHardswish()
#               )
#               (1): Conv2dNormActivation(
#                 (0): QuantizedConv2d(480, 480, kernel_size=(3, 3), stride=(1, 1), scale=264.3436279296875, zero_point=103, padding=(1, 1), groups=480, bias=False)
#                 (1): QuantizedBatchNorm2d(480, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                 (2): QuantizedHardswish()
#               )
#               (2): QuantizableSqueezeExcitation(
#                 (avgpool): AdaptiveAvgPool2d(output_size=1)
#                 (fc1): QuantizedConv2d(480, 20, kernel_size=(1, 1), stride=(1, 1), scale=23.715435028076172, zero_point=33)
#                 (fc2): QuantizedConv2d(20, 480, kernel_size=(1, 1), stride=(1, 1), scale=51.41118240356445, zero_point=69)
#                 (activation): QuantizedHardswish()
#                 (scale_activation): Hardsigmoid()
#                 (skip_mul): QFunctional(
#                   scale=385.6001892089844, zero_point=0
#                   (activation_post_process): Identity()
#                 )
#               )
#               (3): Conv2dNormActivation(
#                 (0): QuantizedConv2d(480, 80, kernel_size=(1, 1), stride=(1, 1), scale=490.4180908203125, zero_point=65, bias=False)
#                 (1): QuantizedBatchNorm2d(80, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               )
#             )
#             (stochastic_depth): StochasticDepth(p=0.08695652173913043, mode=row)
#             (f_add): QFunctional(
#               scale=2284.528564453125, zero_point=79
#               (activation_post_process): Identity()
#             )
#           )
#           (3): QuantizableMBConv(
#             (block): Sequential(
#               (0): Conv2dNormActivation(
#                 (0): QuantizedConv2d(80, 480, kernel_size=(1, 1), stride=(1, 1), scale=10224.5166015625, zero_point=63, bias=False)
#                 (1): QuantizedBatchNorm2d(480, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                 (2): QuantizedHardswish()
#               )
#               (1): Conv2dNormActivation(
#                 (0): QuantizedConv2d(480, 480, kernel_size=(3, 3), stride=(1, 1), scale=776.6825561523438, zero_point=45, padding=(1, 1), groups=480, bias=False)
#                 (1): QuantizedBatchNorm2d(480, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                 (2): QuantizedHardswish()
#               )
#               (2): QuantizableSqueezeExcitation(
#                 (avgpool): AdaptiveAvgPool2d(output_size=1)
#                 (fc1): QuantizedConv2d(480, 20, kernel_size=(1, 1), stride=(1, 1), scale=14.370637893676758, zero_point=74)
#                 (fc2): QuantizedConv2d(20, 480, kernel_size=(1, 1), stride=(1, 1), scale=21.968769073486328, zero_point=90)
#                 (activation): QuantizedHardswish()
#                 (scale_activation): Hardsigmoid()
#                 (skip_mul): QFunctional(
#                   scale=2342.89306640625, zero_point=0
#                   (activation_post_process): Identity()
#                 )
#               )
#               (3): Conv2dNormActivation(
#                 (0): QuantizedConv2d(480, 80, kernel_size=(1, 1), stride=(1, 1), scale=2632.49072265625, zero_point=57, bias=False)
#                 (1): QuantizedBatchNorm2d(80, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               )
#             )
#             (stochastic_depth): StochasticDepth(p=0.09565217391304348, mode=row)
#             (f_add): QFunctional(
#               scale=8191.22802734375, zero_point=63
#               (activation_post_process): Identity()
#             )
#           )
#         )
#         (5): Sequential(
#           (0): QuantizableMBConv(
#             (block): Sequential(
#               (0): Conv2dNormActivation(
#                 (0): QuantizedConv2d(80, 480, kernel_size=(1, 1), stride=(1, 1), scale=28562.10546875, zero_point=46, bias=False)
#                 (1): QuantizedBatchNorm2d(480, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                 (2): QuantizedHardswish()
#               )
#               (1): Conv2dNormActivation(
#                 (0): QuantizedConv2d(480, 480, kernel_size=(5, 5), stride=(1, 1), scale=5889.8447265625, zero_point=52, padding=(2, 2), groups=480, bias=False)
#                 (1): QuantizedBatchNorm2d(480, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                 (2): QuantizedHardswish()
#               )
#               (2): QuantizableSqueezeExcitation(
#                 (avgpool): AdaptiveAvgPool2d(output_size=1)
#                 (fc1): QuantizedConv2d(480, 20, kernel_size=(1, 1), stride=(1, 1), scale=120.17208862304688, zero_point=41)
#                 (fc2): QuantizedConv2d(20, 480, kernel_size=(1, 1), stride=(1, 1), scale=388.77252197265625, zero_point=69)
#                 (activation): QuantizedHardswish()
#                 (scale_activation): Hardsigmoid()
#                 (skip_mul): QFunctional(
#                   scale=874.5784912109375, zero_point=0
#                   (activation_post_process): Identity()
#                 )
#               )
#               (3): Conv2dNormActivation(
#                 (0): QuantizedConv2d(480, 112, kernel_size=(1, 1), stride=(1, 1), scale=1680.279296875, zero_point=66, bias=False)
#                 (1): QuantizedBatchNorm2d(112, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               )
#             )
#             (stochastic_depth): StochasticDepth(p=0.10434782608695654, mode=row)
#             (f_add): QFunctional(
#               scale=1.0, zero_point=0
#               (activation_post_process): Identity()
#             )
#           )
#           (1): QuantizableMBConv(
#             (block): Sequential(
#               (0): Conv2dNormActivation(
#                 (0): QuantizedConv2d(112, 672, kernel_size=(1, 1), stride=(1, 1), scale=12033.73828125, zero_point=72, bias=False)
#                 (1): QuantizedBatchNorm2d(672, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                 (2): QuantizedHardswish()
#               )
#               (1): Conv2dNormActivation(
#                 (0): QuantizedConv2d(672, 672, kernel_size=(5, 5), stride=(1, 1), scale=3090.38720703125, zero_point=53, padding=(2, 2), groups=672, bias=False)
#                 (1): QuantizedBatchNorm2d(672, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                 (2): QuantizedHardswish()
#               )
#               (2): QuantizableSqueezeExcitation(
#                 (avgpool): AdaptiveAvgPool2d(output_size=1)
#                 (fc1): QuantizedConv2d(672, 28, kernel_size=(1, 1), stride=(1, 1), scale=109.33943939208984, zero_point=68)
#                 (fc2): QuantizedConv2d(28, 672, kernel_size=(1, 1), stride=(1, 1), scale=125.57081604003906, zero_point=78)
#                 (activation): QuantizedHardswish()
#                 (scale_activation): Hardsigmoid()
#                 (skip_mul): QFunctional(
#                   scale=2262.78955078125, zero_point=0
#                   (activation_post_process): Identity()
#                 )
#               )
#               (3): Conv2dNormActivation(
#                 (0): QuantizedConv2d(672, 112, kernel_size=(1, 1), stride=(1, 1), scale=1958.6683349609375, zero_point=58, bias=False)
#                 (1): QuantizedBatchNorm2d(112, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               )
#             )
#             (stochastic_depth): StochasticDepth(p=0.11304347826086956, mode=row)
#             (f_add): QFunctional(
#               scale=10772.4892578125, zero_point=58
#               (activation_post_process): Identity()
#             )
#           )
#           (2): QuantizableMBConv(
#             (block): Sequential(
#               (0): Conv2dNormActivation(
#                 (0): QuantizedConv2d(112, 672, kernel_size=(1, 1), stride=(1, 1), scale=16498.03515625, zero_point=72, bias=False)
#                 (1): QuantizedBatchNorm2d(672, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                 (2): QuantizedHardswish()
#               )
#               (1): Conv2dNormActivation(
#                 (0): QuantizedConv2d(672, 672, kernel_size=(5, 5), stride=(1, 1), scale=1293.404541015625, zero_point=70, padding=(2, 2), groups=672, bias=False)
#                 (1): QuantizedBatchNorm2d(672, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                 (2): QuantizedHardswish()
#               )
#               (2): QuantizableSqueezeExcitation(
#                 (avgpool): AdaptiveAvgPool2d(output_size=1)
#                 (fc1): QuantizedConv2d(672, 28, kernel_size=(1, 1), stride=(1, 1), scale=112.96136474609375, zero_point=83)
#                 (fc2): QuantizedConv2d(28, 672, kernel_size=(1, 1), stride=(1, 1), scale=146.14508056640625, zero_point=53)
#                 (activation): QuantizedHardswish()
#                 (scale_activation): Hardsigmoid()
#                 (skip_mul): QFunctional(
#                   scale=4115.46044921875, zero_point=0
#                   (activation_post_process): Identity()
#                 )
#               )
#               (3): Conv2dNormActivation(
#                 (0): QuantizedConv2d(672, 112, kernel_size=(1, 1), stride=(1, 1), scale=4544.58544921875, zero_point=63, bias=False)
#                 (1): QuantizedBatchNorm2d(112, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               )
#             )
#             (stochastic_depth): StochasticDepth(p=0.12173913043478261, mode=row)
#             (f_add): QFunctional(
#               scale=21163.8125, zero_point=71
#               (activation_post_process): Identity()
#             )
#           )
#           (3): QuantizableMBConv(
#             (block): Sequential(
#               (0): Conv2dNormActivation(
#                 (0): QuantizedConv2d(112, 672, kernel_size=(1, 1), stride=(1, 1), scale=42632.1171875, zero_point=77, bias=False)
#                 (1): QuantizedBatchNorm2d(672, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                 (2): QuantizedHardswish()
#               )
#               (1): Conv2dNormActivation(
#                 (0): QuantizedConv2d(672, 672, kernel_size=(5, 5), stride=(1, 1), scale=2813.49951171875, zero_point=52, padding=(2, 2), groups=672, bias=False)
#                 (1): QuantizedBatchNorm2d(672, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                 (2): QuantizedHardswish()
#               )
#               (2): QuantizableSqueezeExcitation(
#                 (avgpool): AdaptiveAvgPool2d(output_size=1)
#                 (fc1): QuantizedConv2d(672, 28, kernel_size=(1, 1), stride=(1, 1), scale=319.5412292480469, zero_point=70)
#                 (fc2): QuantizedConv2d(28, 672, kernel_size=(1, 1), stride=(1, 1), scale=447.0268249511719, zero_point=62)
#                 (activation): QuantizedHardswish()
#                 (scale_activation): Hardsigmoid()
#                 (skip_mul): QFunctional(
#                   scale=2289.927734375, zero_point=0
#                   (activation_post_process): Identity()
#                 )
#               )
#               (3): Conv2dNormActivation(
#                 (0): QuantizedConv2d(672, 112, kernel_size=(1, 1), stride=(1, 1), scale=2684.471435546875, zero_point=60, bias=False)
#                 (1): QuantizedBatchNorm2d(112, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               )
#             )
#             (stochastic_depth): StochasticDepth(p=0.13043478260869565, mode=row)
#             (f_add): QFunctional(
#               scale=18895.650390625, zero_point=66
#               (activation_post_process): Identity()
#             )
#           )
#         )
#         (6): Sequential(
#           (0): QuantizableMBConv(
#             (block): Sequential(
#               (0): Conv2dNormActivation(
#                 (0): QuantizedConv2d(112, 672, kernel_size=(1, 1), stride=(1, 1), scale=55465.90625, zero_point=58, bias=False)
#                 (1): QuantizedBatchNorm2d(672, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                 (2): QuantizedHardswish()
#               )
#               (1): Conv2dNormActivation(
#                 (0): QuantizedConv2d(672, 672, kernel_size=(5, 5), stride=(2, 2), scale=3323.366455078125, zero_point=78, padding=(2, 2), groups=672, bias=False)
#                 (1): QuantizedBatchNorm2d(672, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                 (2): QuantizedHardswish()
#               )
#               (2): QuantizableSqueezeExcitation(
#                 (avgpool): AdaptiveAvgPool2d(output_size=1)
#                 (fc1): QuantizedConv2d(672, 28, kernel_size=(1, 1), stride=(1, 1), scale=18.881120681762695, zero_point=103)
#                 (fc2): QuantizedConv2d(28, 672, kernel_size=(1, 1), stride=(1, 1), scale=1.5035291910171509, zero_point=65)
#                 (activation): QuantizedHardswish()
#                 (scale_activation): Hardsigmoid()
#                 (skip_mul): QFunctional(
#                   scale=5351.33935546875, zero_point=0
#                   (activation_post_process): Identity()
#                 )
#               )
#               (3): Conv2dNormActivation(
#                 (0): QuantizedConv2d(672, 192, kernel_size=(1, 1), stride=(1, 1), scale=19278.33984375, zero_point=74, bias=False)
#                 (1): QuantizedBatchNorm2d(192, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               )
#             )
#             (stochastic_depth): StochasticDepth(p=0.1391304347826087, mode=row)
#             (f_add): QFunctional(
#               scale=1.0, zero_point=0
#               (activation_post_process): Identity()
#             )
#           )
#           (1): QuantizableMBConv(
#             (block): Sequential(
#               (0): Conv2dNormActivation(
#                 (0): QuantizedConv2d(192, 1152, kernel_size=(1, 1), stride=(1, 1), scale=81679.515625, zero_point=89, bias=False)
#                 (1): QuantizedBatchNorm2d(1152, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                 (2): QuantizedHardswish()
#               )
#               (1): Conv2dNormActivation(
#                 (0): QuantizedConv2d(1152, 1152, kernel_size=(5, 5), stride=(1, 1), scale=4107.60791015625, zero_point=113, padding=(2, 2), groups=1152, bias=False)
#                 (1): QuantizedBatchNorm2d(1152, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                 (2): QuantizedHardswish()
#               )
#               (2): QuantizableSqueezeExcitation(
#                 (avgpool): AdaptiveAvgPool2d(output_size=1)
#                 (fc1): QuantizedConv2d(1152, 48, kernel_size=(1, 1), stride=(1, 1), scale=407.67578125, zero_point=53)
#                 (fc2): QuantizedConv2d(48, 1152, kernel_size=(1, 1), stride=(1, 1), scale=506.9852294921875, zero_point=84)
#                 (activation): QuantizedHardswish()
#                 (scale_activation): Hardsigmoid()
#                 (skip_mul): QFunctional(
#                   scale=3655.9775390625, zero_point=0
#                   (activation_post_process): Identity()
#                 )
#               )
#               (3): Conv2dNormActivation(
#                 (0): QuantizedConv2d(1152, 192, kernel_size=(1, 1), stride=(1, 1), scale=2671.215576171875, zero_point=64, bias=False)
#                 (1): QuantizedBatchNorm2d(192, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               )
#             )
#             (stochastic_depth): StochasticDepth(p=0.14782608695652175, mode=row)
#             (f_add): QFunctional(
#               scale=34449.76953125, zero_point=69
#               (activation_post_process): Identity()
#             )
#           )
#           (2): QuantizableMBConv(
#             (block): Sequential(
#               (0): Conv2dNormActivation(
#                 (0): QuantizedConv2d(192, 1152, kernel_size=(1, 1), stride=(1, 1), scale=86603.90625, zero_point=86, bias=False)
#                 (1): QuantizedBatchNorm2d(1152, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                 (2): QuantizedHardswish()
#               )
#               (1): Conv2dNormActivation(
#                 (0): QuantizedConv2d(1152, 1152, kernel_size=(5, 5), stride=(1, 1), scale=8020.76220703125, zero_point=115, padding=(2, 2), groups=1152, bias=False)
#                 (1): QuantizedBatchNorm2d(1152, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                 (2): QuantizedHardswish()
#               )
#               (2): QuantizableSqueezeExcitation(
#                 (avgpool): AdaptiveAvgPool2d(output_size=1)
#                 (fc1): QuantizedConv2d(1152, 48, kernel_size=(1, 1), stride=(1, 1), scale=795.9909057617188, zero_point=70)
#                 (fc2): QuantizedConv2d(48, 1152, kernel_size=(1, 1), stride=(1, 1), scale=739.5307006835938, zero_point=75)
#                 (activation): QuantizedHardswish()
#                 (scale_activation): Hardsigmoid()
#                 (skip_mul): QFunctional(
#                   scale=2901.508544921875, zero_point=0
#                   (activation_post_process): Identity()
#                 )
#               )
#               (3): Conv2dNormActivation(
#                 (0): QuantizedConv2d(1152, 192, kernel_size=(1, 1), stride=(1, 1), scale=1922.786376953125, zero_point=74, bias=False)
#                 (1): QuantizedBatchNorm2d(192, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               )
#             )
#             (stochastic_depth): StochasticDepth(p=0.1565217391304348, mode=row)
#             (f_add): QFunctional(
#               scale=34116.984375, zero_point=69
#               (activation_post_process): Identity()
#             )
#           )
#           (3): QuantizableMBConv(
#             (block): Sequential(
#               (0): Conv2dNormActivation(
#                 (0): QuantizedConv2d(192, 1152, kernel_size=(1, 1), stride=(1, 1), scale=111581.6796875, zero_point=75, bias=False)
#                 (1): QuantizedBatchNorm2d(1152, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                 (2): QuantizedHardswish()
#               )
#               (1): Conv2dNormActivation(
#                 (0): QuantizedConv2d(1152, 1152, kernel_size=(5, 5), stride=(1, 1), scale=5474.01123046875, zero_point=73, padding=(2, 2), groups=1152, bias=False)
#                 (1): QuantizedBatchNorm2d(1152, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                 (2): QuantizedHardswish()
#               )
#               (2): QuantizableSqueezeExcitation(
#                 (avgpool): AdaptiveAvgPool2d(output_size=1)
#                 (fc1): QuantizedConv2d(1152, 48, kernel_size=(1, 1), stride=(1, 1), scale=988.7603149414062, zero_point=68)
#                 (fc2): QuantizedConv2d(48, 1152, kernel_size=(1, 1), stride=(1, 1), scale=1009.9954223632812, zero_point=98)
#                 (activation): QuantizedHardswish()
#                 (scale_activation): Hardsigmoid()
#                 (skip_mul): QFunctional(
#                   scale=1756.7139892578125, zero_point=0
#                   (activation_post_process): Identity()
#                 )
#               )
#               (3): Conv2dNormActivation(
#                 (0): QuantizedConv2d(1152, 192, kernel_size=(1, 1), stride=(1, 1), scale=1552.566162109375, zero_point=54, bias=False)
#                 (1): QuantizedBatchNorm2d(192, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               )
#             )
#             (stochastic_depth): StochasticDepth(p=0.16521739130434784, mode=row)
#             (f_add): QFunctional(
#               scale=34225.875, zero_point=68
#               (activation_post_process): Identity()
#             )
#           )
#           (4): QuantizableMBConv(
#             (block): Sequential(
#               (0): Conv2dNormActivation(
#                 (0): QuantizedConv2d(192, 1152, kernel_size=(1, 1), stride=(1, 1), scale=115952.34375, zero_point=81, bias=False)
#                 (1): QuantizedBatchNorm2d(1152, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                 (2): QuantizedHardswish()
#               )
#               (1): Conv2dNormActivation(
#                 (0): QuantizedConv2d(1152, 1152, kernel_size=(5, 5), stride=(1, 1), scale=5975.55859375, zero_point=89, padding=(2, 2), groups=1152, bias=False)
#                 (1): QuantizedBatchNorm2d(1152, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                 (2): QuantizedHardswish()
#               )
#               (2): QuantizableSqueezeExcitation(
#                 (avgpool): AdaptiveAvgPool2d(output_size=1)
#                 (fc1): QuantizedConv2d(1152, 48, kernel_size=(1, 1), stride=(1, 1), scale=987.7857055664062, zero_point=62)
#                 (fc2): QuantizedConv2d(48, 1152, kernel_size=(1, 1), stride=(1, 1), scale=1020.2972412109375, zero_point=86)
#                 (activation): QuantizedHardswish()
#                 (scale_activation): Hardsigmoid()
#                 (skip_mul): QFunctional(
#                   scale=2473.572021484375, zero_point=0
#                   (activation_post_process): Identity()
#                 )
#               )
#               (3): Conv2dNormActivation(
#                 (0): QuantizedConv2d(1152, 192, kernel_size=(1, 1), stride=(1, 1), scale=2196.29541015625, zero_point=56, bias=False)
#                 (1): QuantizedBatchNorm2d(192, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               )
#             )
#             (stochastic_depth): StochasticDepth(p=0.17391304347826086, mode=row)
#             (f_add): QFunctional(
#               scale=36186.99609375, zero_point=71
#               (activation_post_process): Identity()
#             )
#           )
#         )
#         (7): Sequential(
#           (0): QuantizableMBConv(
#             (block): Sequential(
#               (0): Conv2dNormActivation(
#                 (0): QuantizedConv2d(192, 1152, kernel_size=(1, 1), stride=(1, 1), scale=213146.046875, zero_point=64, bias=False)
#                 (1): QuantizedBatchNorm2d(1152, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                 (2): QuantizedHardswish()
#               )
#               (1): Conv2dNormActivation(
#                 (0): QuantizedConv2d(1152, 1152, kernel_size=(3, 3), stride=(1, 1), scale=7483.1708984375, zero_point=62, padding=(1, 1), groups=1152, bias=False)
#                 (1): QuantizedBatchNorm2d(1152, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                 (2): QuantizedHardswish()
#               )
#               (2): QuantizableSqueezeExcitation(
#                 (avgpool): AdaptiveAvgPool2d(output_size=1)
#                 (fc1): QuantizedConv2d(1152, 48, kernel_size=(1, 1), stride=(1, 1), scale=219.46434020996094, zero_point=59)
#                 (fc2): QuantizedConv2d(48, 1152, kernel_size=(1, 1), stride=(1, 1), scale=606.809814453125, zero_point=55)
#                 (activation): QuantizedHardswish()
#                 (scale_activation): Hardsigmoid()
#                 (skip_mul): QFunctional(
#                   scale=3361.528564453125, zero_point=0
#                   (activation_post_process): Identity()
#                 )
#               )
#               (3): Conv2dNormActivation(
#                 (0): QuantizedConv2d(1152, 320, kernel_size=(1, 1), stride=(1, 1), scale=24166.58203125, zero_point=71, bias=False)
#                 (1): QuantizedBatchNorm2d(320, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               )
#             )
#             (stochastic_depth): StochasticDepth(p=0.1826086956521739, mode=row)
#             (f_add): QFunctional(
#               scale=1.0, zero_point=0
#               (activation_post_process): Identity()
#             )
#           )
#           (1): QuantizableMBConv(
#             (block): Sequential(
#               (0): Conv2dNormActivation(
#                 (0): QuantizedConv2d(320, 1920, kernel_size=(1, 1), stride=(1, 1), scale=121262.484375, zero_point=77, bias=False)
#                 (1): QuantizedBatchNorm2d(1920, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                 (2): QuantizedHardswish()
#               )
#               (1): Conv2dNormActivation(
#                 (0): QuantizedConv2d(1920, 1920, kernel_size=(3, 3), stride=(1, 1), scale=7904.70751953125, zero_point=85, padding=(1, 1), groups=1920, bias=False)
#                 (1): QuantizedBatchNorm2d(1920, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                 (2): QuantizedHardswish()
#               )
#               (2): QuantizableSqueezeExcitation(
#                 (avgpool): AdaptiveAvgPool2d(output_size=1)
#                 (fc1): QuantizedConv2d(1920, 80, kernel_size=(1, 1), stride=(1, 1), scale=2676.397705078125, zero_point=22)
#                 (fc2): QuantizedConv2d(80, 1920, kernel_size=(1, 1), stride=(1, 1), scale=4883.91943359375, zero_point=93)
#                 (activation): QuantizedHardswish()
#                 (scale_activation): Hardsigmoid()
#                 (skip_mul): QFunctional(
#                   scale=1671.9449462890625, zero_point=0
#                   (activation_post_process): Identity()
#                 )
#               )
#               (3): Conv2dNormActivation(
#                 (0): QuantizedConv2d(1920, 320, kernel_size=(1, 1), stride=(1, 1), scale=3339.840576171875, zero_point=48, bias=False)
#                 (1): QuantizedBatchNorm2d(320, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               )
#             )
#             (stochastic_depth): StochasticDepth(p=0.19130434782608696, mode=row)
#             (f_add): QFunctional(
#               scale=67468.9921875, zero_point=66
#               (activation_post_process): Identity()
#             )
#           )
#         )
#         (8): Conv2dNormActivation(
#           (0): QuantizedConv2d(320, 1280, kernel_size=(1, 1), stride=(1, 1), scale=51099.67578125, zero_point=122, bias=False)
#           (1): QuantizedBatchNorm2d(1280, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): QuantizedHardswish()
#         )
#       )
#       (avgpool): AdaptiveAvgPool2d(output_size=1)
#       (classifier): Sequential(
#         (0): QuantizedDropout(p=0.2, inplace=True)
#         (1): Identity()
#       )
#     )
#   )
#   (1): G0: (0.000377, 0.811099), G1: (0.000057, 0.779696), G2: (0.000010, 0.797757)
#   (2): QuantWrapper(
#     (quant): Quantize(scale=tensor([536.9240]), zero_point=tensor([0]), dtype=torch.quint8)
#     (dequant): DeQuantize()
#     (module): QuantizedLinear(in_features=1280, out_features=1, scale=82.7070541381836, zero_point=0, qscheme=torch.per_channel_affine)
#   )
# )

# %%
test_loss, test_acc, test_auc, tst_preds, tst_gts, tst_attrs, tst_pred_gt_by_attrs, tst_other_metrics = validation(qmodel, criterion, optimizer, validation_dataset_loader, epoch, identity_Info=imb_info, _device='cpu')
# Out:
# cpu
# test <==== epcoh 5 loss: 3987.0296 auc: 0.5102
# 0-attr auc: 0.4984
# 1-attr auc: 0.5182
# 2-attr auc: 0.5118

# %%
forward_model_with_fin(qmodel, i[0], i[2]), i[1]
# Out:
# ((tensor([[ 1571.4341],
#           [12075.2295],
#           [ 4879.7163],
#           [17533.8945],
#           [10421.0889],
#           [ 6451.1504]]),
#   tensor([[ 5.4292e+02, -5.8519e-03,  5.6278e+02,  ...,  5.2520e+02,
#             2.0309e-02,  1.4293e+03],
#           [ 1.0364e+03,  1.8478e+03,  8.7756e+03,  ...,  8.9955e+02,
#             3.5601e+03,  2.4749e+03],
#           [-5.5711e-03,  6.1593e+02,  2.1939e+03,  ...,  4.4977e+02,
#             1.4241e+03,  1.9352e-02],
#           [ 1.0364e+03,  7.3910e+03,  6.5817e+03,  ...,  3.1485e+03,
#             2.8481e+03,  4.1247e+03],
#           [ 1.0364e+03,  2.4637e+03,  8.7756e+03,  ...,  8.9955e+02,
#             1.4241e+03,  2.4749e+03],
#           [ 6.2375e+02,  9.3059e+03,  1.9183e+03,  ...,  2.3414e+02,
#             2.6367e+03,  1.4994e+03]], grad_fn=<CopySlices>)),
#  tensor([1., 1., 0., 0., 1., 1.]))

# %%
forward_model_with_fin(model.to('cpu'), i[0], i[2]), i[1]
# Out:
# ((tensor([[ 1.3384],
#           [ 2.5935],
#           [-1.0915],
#           [-0.9906],
#           [-1.3039],
#           [ 1.6806]], grad_fn=<MmBackward0>),
#   tensor([[-0.0710,  0.5979,  0.3407,  ...,  0.4270,  0.3172,  0.0049],
#           [-0.0826,  0.0116,  1.4590,  ..., -0.1726,  0.0186,  0.1054],
#           [ 0.1008, -0.3759, -0.3595,  ...,  0.0357, -0.3483,  0.0250],
#           [ 0.3190,  0.1690,  0.0527,  ..., -0.0835, -0.0580, -0.2341],
#           [ 0.0390, -0.1434, -0.6564,  ...,  0.5235, -0.2372,  0.0250],
#           [ 0.0070,  1.2618,  0.4286,  ..., -0.0641,  1.1384, -0.0683]],
#          grad_fn=<AsStridedBackward0>)),
#  tensor([1., 1., 0., 0., 1., 1.]))
