# %% [markdown]
# # Post Hoc Quantisation of RNLFT Models

# %%
import os
import argparse
import random
import time
import json

import numpy as np
import torch
import torch.nn as nn
from torch.optim.lr_scheduler import *
from torch.optim import *
import torch.nn.functional as F

from sklearn.metrics import *
from sklearn.model_selection import KFold

import sys
sys.path.append('.')

from src.modules import *
from src.data_handler import *
from src import logger
from src.class_balanced_loss import *
from typing import NamedTuple
from torchvision.models import efficientnet as efn

from train_glaucoma_fair_fin import train, validation, Identity_Info, quantifiable_efficientnet

from fairlearn.metrics import *

imb_info = Identity_Info()

# %%
out_dim = 1
criterion = nn.BCEWithLogitsLoss()
predictor_head = nn.Sigmoid()
in_feat_to_final = 1280
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

fin_mu = 0.01
fin_sigma = 1.
fin_momentum = 0.3
model_type = 'resnext'  # or quant
modality_types = 'rnflt'
task = 'cls'
pretrained_weights = 'results/crosssectional_rnflt_fin_race_ablation_of_sigma/fullysup_efficientnet_rnflt_Taskcls_lr5e-5_bz6_564_auc0.8569/last_weights.pth'
pretrained_weights = 'results/crosssectional_rnflt_fin_race_ablation_of_sigma/fullysup_efficientnet_rnflt_Taskcls_lr5e-5_bz6_564_auc0.8569/best_weights.pth'
pretrained_weights = 'results/crosssectional_rnflt_fin_race_ablation_of_sigma/fullysup_quant_rnflt_Taskcls_lr5e-5_bz6_4442_auc0.7311/best_weights.pth'
pretrained_weights = 'results/crosssectional_rnflt_fin_race_ablation_of_sigma/fullysup_quant_rnflt_Taskcls_lr5e-5_bz6_9354_auc0.8495/best_weights.pth'
pretrained_weights = 'results/crosssectional_rnflt_fin_race_ablation_of_sigma/fullysup_resnext_rnflt_Taskcls_lr5e-5_bz6_7315_auc0.8513/last_weights.pth'
ag_norm = Fair_Identity_Normalizer(
    3,
    dim=in_feat_to_final,
    mu=fin_mu,
    sigma=fin_sigma,
    momentum=fin_momentum,
)
in_dim = 1
# model = quantifiable_efficientnet(width_mult=1.0, depth_mult=1.0, weights=EfficientNet_B1_Weights.IMAGENET1K_V2)# create_model(model_type=model_type, in_dim=in_dim, out_dim=out_dim, include_final=False)
model = create_model(model_type=model_type, in_dim=in_dim, out_dim=out_dim, include_final=False)
final_layer = nn.Linear(in_features=in_feat_to_final, out_features=out_dim, bias=False)
model = nn.Sequential(model, ag_norm, final_layer)
model = model.to(device)

checkpoint = torch.load(pretrained_weights)

start_epoch = checkpoint['epoch'] + 1
model.load_state_dict(checkpoint['model_state_dict'])
# efnm = create_model(model_type=model_type, in_dim=in_dim, out_dim=out_dim, include_final=False)
# optimizer.load_state_dict(checkpoint['optimizer_state_dict'])
# scaler.load_state_dict(checkpoint['scaler_state_dict'])
# scheduler.load_state_dict(checkpoint['scheduler_state_dict'])
# Out:
# <All keys matched successfully>

# %%
data_dir = "../quant_notes/data_cmpr"
image_size = 200
attribute_type = 'race' 

trn_dataset = EyeFair(
    os.path.join(data_dir, "train"),
    modality_type=modality_types,
    task=task,
    resolution=image_size,
    attribute_type=attribute_type,
    depth=3
)
# Out:
# min: -31.9900, max: 2.2700

# %%
batch_size = 6
validation_dataset_loader = torch.utils.data.DataLoader(trn_dataset, batch_size=batch_size, shuffle=False, pin_memory=True, drop_last=False)

# %%
res = validation(model, criterion, None, validation_dataset_loader, 10, identity_Info=imb_info, _device=device)
res[1]
# Out:
# cuda
# test <==== epcoh 10 loss: 1.7404 auc: 0.9903
# 0-attr auc: 0.9974
# 1-attr auc: 0.9956
# 2-attr auc: 0.9763
# 0.9871428571428571

# %%
def print_size_of_model(model):
    torch.save(model.state_dict(), "temp.p")
    print('Size (MB):', os.path.getsize("temp.p")/1e6)
    os.remove('temp.p')

print_size_of_model(model)
# Out:
# Size (MB): 337.143069

# %%
        # self.quant = QuantStub()
        # self.dequant = DeQuantStub()
from copy import deepcopy

import torch.ao.quantization
qmodel = deepcopy(model)
qmodel[0].fuse_model(is_qat=False)
qmodel[1].v = False
# qmodel = torch.ao.quantization.fuse_modules(model, ['conv2', 'bn2'])
# qmodel[0] = torch.quantization.QuantWrapper(qmodel[0])
qmodel[2] = torch.quantization.QuantWrapper(qmodel[2])
# pre_model_stub = nn.Sequential(torch.ao.quantization.QuantStub(), qmodel[0])
# post_model_stub =  nn.Sequential(qmodel[-1], torch.ao.quantization.DeQuantStub())
# qmodel[0] = pre_model_stub
# qmodel[-1] = post_model_stub

# %%
import torch.ao.quantization


qmodel.eval().to('cpu')
# qconf = torch.quantization.QConfig(
#     activation=torch.quantization.MovingAverageMinMaxObserver.with_args(
#         qscheme=torch.per_tensor_symmetric
#     ),
#     weight=torch.quantization.MovingAveragePerChannelMinMaxObserver.with_args(
#         qscheme=torch.per_channel_symmetric, dtype=torch.qint8
#     ),
# )  # torch.ao.quantization.default_per_channel_qconfig.weight)
qmodel.qconfig = torch.ao.quantization.default_per_channel_qconfig
print(qmodel.qconfig)
torch.ao.quantization.prepare(qmodel, inplace=True)

# Calibrate here
res = validation(
    qmodel,
    criterion,
    None,
    validation_dataset_loader,
    10,
    identity_Info=imb_info,
    _device='cpu',
)
qmodel[1].v = True
# Convert here
torch.ao.quantization.convert(qmodel, inplace=True)
print_size_of_model(qmodel)
# Out:
# QConfig(activation=functools.partial(<class 'torch.ao.quantization.observer.MinMaxObserver'>, quant_min=0, quant_max=127){}, weight=functools.partial(<class 'torch.ao.quantization.observer.PerChannelMinMaxObserver'>, dtype=torch.qint8, qscheme=torch.per_channel_symmetric){})
# cpu
# test <==== epcoh 10 loss: 1.7404 auc: 0.9903
# 0-attr auc: 0.9974
# 1-attr auc: 0.9956
# 2-attr auc: 0.9763
# Size (MB): 86.105431

# %%
with torch.no_grad():
        for i, (x, target, attr) in enumerate(validation_dataset_loader):
            x = x.to(device)
            target = target.to(device)
            attr = attr.to(device)
            break

x.shape, target, attr
# Out:
# (torch.Size([6, 3, 200, 200]),
#  tensor([1., 1., 1., 1., 0., 1.], device='cuda:0'),
#  tensor([2, 1, 0, 1, 1, 0], device='cuda:0', dtype=torch.int32))

# %%
qmodel[1].v=False
res = validation(qmodel, criterion, None, validation_dataset_loader, 10, identity_Info=imb_info, _device=torch.device('cpu'))

res[1]
# next(model.parameters()).is_cuda
# Out:
# cpu
# test <==== epcoh 10 loss: 6.2672 auc: 0.4568
# 0-attr auc: 0.4493
# 1-attr auc: 0.3831
# 2-attr auc: 0.4487
# 0.46523809523809523

# %%
res[1]
# Out:
# 0.5071428571428571

# %%
# model
qmodel
# Out:
# Sequential(
#   (0): QuantizableResNet(
#     (conv1): QuantizedConvReLU2d(3, 64, kernel_size=(7, 7), stride=(2, 2), scale=1.8434251546859741, zero_point=0, padding=(3, 3))
#     (bn1): Identity()
#     (relu): Identity()
#     (maxpool): MaxPool2d(kernel_size=3, stride=2, padding=1, dilation=1, ceil_mode=False)
#     (layer1): Sequential(
#       (0): QuantizableBottleneck(
#         (conv1): QuantizedConvReLU2d(64, 256, kernel_size=(1, 1), stride=(1, 1), scale=0.9331411123275757, zero_point=0)
#         (bn1): Identity()
#         (conv2): QuantizedConvReLU2d(256, 256, kernel_size=(3, 3), stride=(1, 1), scale=1.5554529428482056, zero_point=0, padding=(1, 1), groups=64)
#         (bn2): Identity()
#         (conv3): QuantizedConv2d(256, 256, kernel_size=(1, 1), stride=(1, 1), scale=2.313227415084839, zero_point=74)
#         (bn3): Identity()
#         (relu): ReLU()
#         (downsample): Sequential(
#           (0): QuantizedConv2d(64, 256, kernel_size=(1, 1), stride=(1, 1), scale=4.313520431518555, zero_point=85)
#           (1): Identity()
#         )
#         (skip_add_relu): QFunctional(
#           scale=1.2193013429641724, zero_point=0
#           (activation_post_process): Identity()
#         )
#         (relu1): Identity()
#         (relu2): Identity()
#       )
#       (1): QuantizableBottleneck(
#         (conv1): QuantizedConvReLU2d(256, 256, kernel_size=(1, 1), stride=(1, 1), scale=0.8889712691307068, zero_point=0)
#         (bn1): Identity()
#         (conv2): QuantizedConvReLU2d(256, 256, kernel_size=(3, 3), stride=(1, 1), scale=7.9297871589660645, zero_point=0, padding=(1, 1), groups=64)
#         (bn2): Identity()
#         (conv3): QuantizedConv2d(256, 256, kernel_size=(1, 1), stride=(1, 1), scale=9.476662635803223, zero_point=27)
#         (bn3): Identity()
#         (relu): ReLU()
#         (skip_add_relu): QFunctional(
#           scale=7.447853088378906, zero_point=0
#           (activation_post_process): Identity()
#         )
#         (relu1): Identity()
#         (relu2): Identity()
#       )
#       (2): QuantizableBottleneck(
#         (conv1): QuantizedConvReLU2d(256, 256, kernel_size=(1, 1), stride=(1, 1), scale=3.5305862426757812, zero_point=0)
#         (bn1): Identity()
#         (conv2): QuantizedConvReLU2d(256, 256, kernel_size=(3, 3), stride=(1, 1), scale=8.482137680053711, zero_point=0, padding=(1, 1), groups=64)
#         (bn2): Identity()
#         (conv3): QuantizedConv2d(256, 256, kernel_size=(1, 1), stride=(1, 1), scale=17.499460220336914, zero_point=72)
#         (bn3): Identity()
#         (relu): ReLU()
#         (skip_add_relu): QFunctional(
#           scale=7.5450544357299805, zero_point=0
#           (activation_post_process): Identity()
#         )
#         (relu1): Identity()
#         (relu2): Identity()
#       )
#     )
#     (layer2): Sequential(
#       (0): QuantizableBottleneck(
#         (conv1): QuantizedConvReLU2d(256, 512, kernel_size=(1, 1), stride=(1, 1), scale=2.3779234886169434, zero_point=0)
#         (bn1): Identity()
#         (conv2): QuantizedConvReLU2d(512, 512, kernel_size=(3, 3), stride=(2, 2), scale=27.01282501220703, zero_point=0, padding=(1, 1), groups=64)
#         (bn2): Identity()
#         (conv3): QuantizedConv2d(512, 512, kernel_size=(1, 1), stride=(1, 1), scale=45.59953689575195, zero_point=70)
#         (bn3): Identity()
#         (relu): ReLU()
#         (downsample): Sequential(
#           (0): QuantizedConv2d(256, 512, kernel_size=(1, 1), stride=(2, 2), scale=4.930780410766602, zero_point=92)
#           (1): Identity()
#         )
#         (skip_add_relu): QFunctional(
#           scale=18.62758445739746, zero_point=0
#           (activation_post_process): Identity()
#         )
#         (relu1): Identity()
#         (relu2): Identity()
#       )
#       (1): QuantizableBottleneck(
#         (conv1): QuantizedConvReLU2d(512, 512, kernel_size=(1, 1), stride=(1, 1), scale=8.302797317504883, zero_point=0)
#         (bn1): Identity()
#         (conv2): QuantizedConvReLU2d(512, 512, kernel_size=(3, 3), stride=(1, 1), scale=21.681468963623047, zero_point=0, padding=(1, 1), groups=64)
#         (bn2): Identity()
#         (conv3): QuantizedConv2d(512, 512, kernel_size=(1, 1), stride=(1, 1), scale=53.191383361816406, zero_point=84)
#         (bn3): Identity()
#         (relu): ReLU()
#         (skip_add_relu): QFunctional(
#           scale=31.2198543548584, zero_point=0
#           (activation_post_process): Identity()
#         )
#         (relu1): Identity()
#         (relu2): Identity()
#       )
#       (2): QuantizableBottleneck(
#         (conv1): QuantizedConvReLU2d(512, 512, kernel_size=(1, 1), stride=(1, 1), scale=12.738471031188965, zero_point=0)
#         (bn1): Identity()
#         (conv2): QuantizedConvReLU2d(512, 512, kernel_size=(3, 3), stride=(1, 1), scale=19.10901641845703, zero_point=0, padding=(1, 1), groups=64)
#         (bn2): Identity()
#         (conv3): QuantizedConv2d(512, 512, kernel_size=(1, 1), stride=(1, 1), scale=59.80461120605469, zero_point=78)
#         (bn3): Identity()
#         (relu): ReLU()
#         (skip_add_relu): QFunctional(
#           scale=22.97378921508789, zero_point=0
#           (activation_post_process): Identity()
#         )
#         (relu1): Identity()
#         (relu2): Identity()
#       )
#       (3): QuantizableBottleneck(
#         (conv1): QuantizedConvReLU2d(512, 512, kernel_size=(1, 1), stride=(1, 1), scale=10.470756530761719, zero_point=0)
#         (bn1): Identity()
#         (conv2): QuantizedConvReLU2d(512, 512, kernel_size=(3, 3), stride=(1, 1), scale=14.612167358398438, zero_point=0, padding=(1, 1), groups=64)
#         (bn2): Identity()
#         (conv3): QuantizedConv2d(512, 512, kernel_size=(1, 1), stride=(1, 1), scale=34.48750305175781, zero_point=88)
#         (bn3): Identity()
#         (relu): ReLU()
#         (skip_add_relu): QFunctional(
#           scale=27.75998878479004, zero_point=0
#           (activation_post_process): Identity()
#         )
#         (relu1): Identity()
#         (relu2): Identity()
#       )
#     )
#     (layer3): Sequential(
#       (0): QuantizableBottleneck(
#         (conv1): QuantizedConvReLU2d(512, 1024, kernel_size=(1, 1), stride=(1, 1), scale=5.2244486808776855, zero_point=0)
#         (bn1): Identity()
#         (conv2): QuantizedConvReLU2d(1024, 1024, kernel_size=(3, 3), stride=(2, 2), scale=41.300682067871094, zero_point=0, padding=(1, 1), groups=64)
#         (bn2): Identity()
#         (conv3): QuantizedConv2d(1024, 1024, kernel_size=(1, 1), stride=(1, 1), scale=95.33528900146484, zero_point=31)
#         (bn3): Identity()
#         (relu): ReLU()
#         (downsample): Sequential(
#           (0): QuantizedConv2d(512, 1024, kernel_size=(1, 1), stride=(2, 2), scale=32.707191467285156, zero_point=66)
#           (1): Identity()
#         )
#         (skip_add_relu): QFunctional(
#           scale=69.78814697265625, zero_point=0
#           (activation_post_process): Identity()
#         )
#         (relu1): Identity()
#         (relu2): Identity()
#       )
#       (1): QuantizableBottleneck(
#         (conv1): QuantizedConvReLU2d(1024, 1024, kernel_size=(1, 1), stride=(1, 1), scale=19.9210262298584, zero_point=0)
#         (bn1): Identity()
#         (conv2): QuantizedConvReLU2d(1024, 1024, kernel_size=(3, 3), stride=(1, 1), scale=33.17830276489258, zero_point=0, padding=(1, 1), groups=64)
#         (bn2): Identity()
#         (conv3): QuantizedConv2d(1024, 1024, kernel_size=(1, 1), stride=(1, 1), scale=209.01332092285156, zero_point=55)
#         (bn3): Identity()
#         (relu): ReLU()
#         (skip_add_relu): QFunctional(
#           scale=189.0714111328125, zero_point=0
#           (activation_post_process): Identity()
#         )
#         (relu1): Identity()
#         (relu2): Identity()
#       )
#       (2): QuantizableBottleneck(
#         (conv1): QuantizedConvReLU2d(1024, 1024, kernel_size=(1, 1), stride=(1, 1), scale=30.37735366821289, zero_point=0)
#         (bn1): Identity()
#         (conv2): QuantizedConvReLU2d(1024, 1024, kernel_size=(3, 3), stride=(1, 1), scale=51.77394104003906, zero_point=0, padding=(1, 1), groups=64)
#         (bn2): Identity()
#         (conv3): QuantizedConv2d(1024, 1024, kernel_size=(1, 1), stride=(1, 1), scale=348.05853271484375, zero_point=42)
#         (bn3): Identity()
#         (relu): ReLU()
#         (skip_add_relu): QFunctional(
#           scale=231.60830688476562, zero_point=0
#           (activation_post_process): Identity()
#         )
#         (relu1): Identity()
#         (relu2): Identity()
#       )
#       (3): QuantizableBottleneck(
#         (conv1): QuantizedConvReLU2d(1024, 1024, kernel_size=(1, 1), stride=(1, 1), scale=81.4331283569336, zero_point=0)
#         (bn1): Identity()
#         (conv2): QuantizedConvReLU2d(1024, 1024, kernel_size=(3, 3), stride=(1, 1), scale=97.18120574951172, zero_point=0, padding=(1, 1), groups=64)
#         (bn2): Identity()
#         (conv3): QuantizedConv2d(1024, 1024, kernel_size=(1, 1), stride=(1, 1), scale=372.5512390136719, zero_point=89)
#         (bn3): Identity()
#         (relu): ReLU()
#         (skip_add_relu): QFunctional(
#           scale=130.95486450195312, zero_point=0
#           (activation_post_process): Identity()
#         )
#         (relu1): Identity()
#         (relu2): Identity()
#       )
#       (4): QuantizableBottleneck(
#         (conv1): QuantizedConvReLU2d(1024, 1024, kernel_size=(1, 1), stride=(1, 1), scale=13.32190990447998, zero_point=0)
#         (bn1): Identity()
#         (conv2): QuantizedConvReLU2d(1024, 1024, kernel_size=(3, 3), stride=(1, 1), scale=35.49821090698242, zero_point=0, padding=(1, 1), groups=64)
#         (bn2): Identity()
#         (conv3): QuantizedConv2d(1024, 1024, kernel_size=(1, 1), stride=(1, 1), scale=169.67616271972656, zero_point=39)
#         (bn3): Identity()
#         (relu): ReLU()
#         (skip_add_relu): QFunctional(
#           scale=117.90579986572266, zero_point=0
#           (activation_post_process): Identity()
#         )
#         (relu1): Identity()
#         (relu2): Identity()
#       )
#       (5): QuantizableBottleneck(
#         (conv1): QuantizedConvReLU2d(1024, 1024, kernel_size=(1, 1), stride=(1, 1), scale=26.54198455810547, zero_point=0)
#         (bn1): Identity()
#         (conv2): QuantizedConvReLU2d(1024, 1024, kernel_size=(3, 3), stride=(1, 1), scale=60.384788513183594, zero_point=0, padding=(1, 1), groups=64)
#         (bn2): Identity()
#         (conv3): QuantizedConv2d(1024, 1024, kernel_size=(1, 1), stride=(1, 1), scale=178.1772003173828, zero_point=87)
#         (bn3): Identity()
#         (relu): ReLU()
#         (skip_add_relu): QFunctional(
#           scale=161.603515625, zero_point=0
#           (activation_post_process): Identity()
#         )
#         (relu1): Identity()
#         (relu2): Identity()
#       )
#       (6): QuantizableBottleneck(
#         (conv1): QuantizedConvReLU2d(1024, 1024, kernel_size=(1, 1), stride=(1, 1), scale=21.544252395629883, zero_point=0)
#         (bn1): Identity()
#         (conv2): QuantizedConvReLU2d(1024, 1024, kernel_size=(3, 3), stride=(1, 1), scale=60.37010955810547, zero_point=0, padding=(1, 1), groups=64)
#         (bn2): Identity()
#         (conv3): QuantizedConv2d(1024, 1024, kernel_size=(1, 1), stride=(1, 1), scale=257.1768493652344, zero_point=96)
#         (bn3): Identity()
#         (relu): ReLU()
#         (skip_add_relu): QFunctional(
#           scale=172.34637451171875, zero_point=0
#           (activation_post_process): Identity()
#         )
#         (relu1): Identity()
#         (relu2): Identity()
#       )
#       (7): QuantizableBottleneck(
#         (conv1): QuantizedConvReLU2d(1024, 1024, kernel_size=(1, 1), stride=(1, 1), scale=19.197097778320312, zero_point=0)
#         (bn1): Identity()
#         (conv2): QuantizedConvReLU2d(1024, 1024, kernel_size=(3, 3), stride=(1, 1), scale=56.00419616699219, zero_point=0, padding=(1, 1), groups=64)
#         (bn2): Identity()
#         (conv3): QuantizedConv2d(1024, 1024, kernel_size=(1, 1), stride=(1, 1), scale=109.81594848632812, zero_point=107)
#         (bn3): Identity()
#         (relu): ReLU()
#         (skip_add_relu): QFunctional(
#           scale=182.49729919433594, zero_point=0
#           (activation_post_process): Identity()
#         )
#         (relu1): Identity()
#         (relu2): Identity()
#       )
#       (8): QuantizableBottleneck(
#         (conv1): QuantizedConvReLU2d(1024, 1024, kernel_size=(1, 1), stride=(1, 1), scale=27.233976364135742, zero_point=0)
#         (bn1): Identity()
#         (conv2): QuantizedConvReLU2d(1024, 1024, kernel_size=(3, 3), stride=(1, 1), scale=40.983360290527344, zero_point=0, padding=(1, 1), groups=64)
#         (bn2): Identity()
#         (conv3): QuantizedConv2d(1024, 1024, kernel_size=(1, 1), stride=(1, 1), scale=97.6851806640625, zero_point=88)
#         (bn3): Identity()
#         (relu): ReLU()
#         (skip_add_relu): QFunctional(
#           scale=139.10211181640625, zero_point=0
#           (activation_post_process): Identity()
#         )
#         (relu1): Identity()
#         (relu2): Identity()
#       )
#       (9): QuantizableBottleneck(
#         (conv1): QuantizedConvReLU2d(1024, 1024, kernel_size=(1, 1), stride=(1, 1), scale=14.041666984558105, zero_point=0)
#         (bn1): Identity()
#         (conv2): QuantizedConvReLU2d(1024, 1024, kernel_size=(3, 3), stride=(1, 1), scale=26.81429100036621, zero_point=0, padding=(1, 1), groups=64)
#         (bn2): Identity()
#         (conv3): QuantizedConv2d(1024, 1024, kernel_size=(1, 1), stride=(1, 1), scale=43.13847351074219, zero_point=79)
#         (bn3): Identity()
#         (relu): ReLU()
#         (skip_add_relu): QFunctional(
#           scale=131.644287109375, zero_point=0
#           (activation_post_process): Identity()
#         )
#         (relu1): Identity()
#         (relu2): Identity()
#       )
#       (10): QuantizableBottleneck(
#         (conv1): QuantizedConvReLU2d(1024, 1024, kernel_size=(1, 1), stride=(1, 1), scale=10.974881172180176, zero_point=0)
#         (bn1): Identity()
#         (conv2): QuantizedConvReLU2d(1024, 1024, kernel_size=(3, 3), stride=(1, 1), scale=35.963287353515625, zero_point=0, padding=(1, 1), groups=64)
#         (bn2): Identity()
#         (conv3): QuantizedConv2d(1024, 1024, kernel_size=(1, 1), stride=(1, 1), scale=51.45886993408203, zero_point=75)
#         (bn3): Identity()
#         (relu): ReLU()
#         (skip_add_relu): QFunctional(
#           scale=131.60775756835938, zero_point=0
#           (activation_post_process): Identity()
#         )
#         (relu1): Identity()
#         (relu2): Identity()
#       )
#       (11): QuantizableBottleneck(
#         (conv1): QuantizedConvReLU2d(1024, 1024, kernel_size=(1, 1), stride=(1, 1), scale=10.028610229492188, zero_point=0)
#         (bn1): Identity()
#         (conv2): QuantizedConvReLU2d(1024, 1024, kernel_size=(3, 3), stride=(1, 1), scale=24.10454559326172, zero_point=0, padding=(1, 1), groups=64)
#         (bn2): Identity()
#         (conv3): QuantizedConv2d(1024, 1024, kernel_size=(1, 1), stride=(1, 1), scale=40.22544479370117, zero_point=88)
#         (bn3): Identity()
#         (relu): ReLU()
#         (skip_add_relu): QFunctional(
#           scale=130.8035888671875, zero_point=0
#           (activation_post_process): Identity()
#         )
#         (relu1): Identity()
#         (relu2): Identity()
#       )
#       (12): QuantizableBottleneck(
#         (conv1): QuantizedConvReLU2d(1024, 1024, kernel_size=(1, 1), stride=(1, 1), scale=14.904009819030762, zero_point=0)
#         (bn1): Identity()
#         (conv2): QuantizedConvReLU2d(1024, 1024, kernel_size=(3, 3), stride=(1, 1), scale=104.55720520019531, zero_point=0, padding=(1, 1), groups=64)
#         (bn2): Identity()
#         (conv3): QuantizedConv2d(1024, 1024, kernel_size=(1, 1), stride=(1, 1), scale=166.2105712890625, zero_point=100)
#         (bn3): Identity()
#         (relu): ReLU()
#         (skip_add_relu): QFunctional(
#           scale=122.30313110351562, zero_point=0
#           (activation_post_process): Identity()
#         )
#         (relu1): Identity()
#         (relu2): Identity()
#       )
#       (13): QuantizableBottleneck(
#         (conv1): QuantizedConvReLU2d(1024, 1024, kernel_size=(1, 1), stride=(1, 1), scale=4.367208480834961, zero_point=0)
#         (bn1): Identity()
#         (conv2): QuantizedConvReLU2d(1024, 1024, kernel_size=(3, 3), stride=(1, 1), scale=19.121835708618164, zero_point=0, padding=(1, 1), groups=64)
#         (bn2): Identity()
#         (conv3): QuantizedConv2d(1024, 1024, kernel_size=(1, 1), stride=(1, 1), scale=25.11726188659668, zero_point=71)
#         (bn3): Identity()
#         (relu): ReLU()
#         (skip_add_relu): QFunctional(
#           scale=122.11822509765625, zero_point=0
#           (activation_post_process): Identity()
#         )
#         (relu1): Identity()
#         (relu2): Identity()
#       )
#       (14): QuantizableBottleneck(
#         (conv1): QuantizedConvReLU2d(1024, 1024, kernel_size=(1, 1), stride=(1, 1), scale=9.581619262695312, zero_point=0)
#         (bn1): Identity()
#         (conv2): QuantizedConvReLU2d(1024, 1024, kernel_size=(3, 3), stride=(1, 1), scale=14.20533275604248, zero_point=0, padding=(1, 1), groups=64)
#         (bn2): Identity()
#         (conv3): QuantizedConv2d(1024, 1024, kernel_size=(1, 1), stride=(1, 1), scale=33.7552375793457, zero_point=94)
#         (bn3): Identity()
#         (relu): ReLU()
#         (skip_add_relu): QFunctional(
#           scale=123.82319641113281, zero_point=0
#           (activation_post_process): Identity()
#         )
#         (relu1): Identity()
#         (relu2): Identity()
#       )
#       (15): QuantizableBottleneck(
#         (conv1): QuantizedConvReLU2d(1024, 1024, kernel_size=(1, 1), stride=(1, 1), scale=8.221038818359375, zero_point=0)
#         (bn1): Identity()
#         (conv2): QuantizedConvReLU2d(1024, 1024, kernel_size=(3, 3), stride=(1, 1), scale=27.06757354736328, zero_point=0, padding=(1, 1), groups=64)
#         (bn2): Identity()
#         (conv3): QuantizedConv2d(1024, 1024, kernel_size=(1, 1), stride=(1, 1), scale=27.96776580810547, zero_point=98)
#         (bn3): Identity()
#         (relu): ReLU()
#         (skip_add_relu): QFunctional(
#           scale=124.8944320678711, zero_point=0
#           (activation_post_process): Identity()
#         )
#         (relu1): Identity()
#         (relu2): Identity()
#       )
#       (16): QuantizableBottleneck(
#         (conv1): QuantizedConvReLU2d(1024, 1024, kernel_size=(1, 1), stride=(1, 1), scale=5.1642255783081055, zero_point=0)
#         (bn1): Identity()
#         (conv2): QuantizedConvReLU2d(1024, 1024, kernel_size=(3, 3), stride=(1, 1), scale=15.380681037902832, zero_point=0, padding=(1, 1), groups=64)
#         (bn2): Identity()
#         (conv3): QuantizedConv2d(1024, 1024, kernel_size=(1, 1), stride=(1, 1), scale=26.801584243774414, zero_point=106)
#         (bn3): Identity()
#         (relu): ReLU()
#         (skip_add_relu): QFunctional(
#           scale=124.15424346923828, zero_point=0
#           (activation_post_process): Identity()
#         )
#         (relu1): Identity()
#         (relu2): Identity()
#       )
#       (17): QuantizableBottleneck(
#         (conv1): QuantizedConvReLU2d(1024, 1024, kernel_size=(1, 1), stride=(1, 1), scale=7.873706817626953, zero_point=0)
#         (bn1): Identity()
#         (conv2): QuantizedConvReLU2d(1024, 1024, kernel_size=(3, 3), stride=(1, 1), scale=24.80050277709961, zero_point=0, padding=(1, 1), groups=64)
#         (bn2): Identity()
#         (conv3): QuantizedConv2d(1024, 1024, kernel_size=(1, 1), stride=(1, 1), scale=50.907196044921875, zero_point=80)
#         (bn3): Identity()
#         (relu): ReLU()
#         (skip_add_relu): QFunctional(
#           scale=126.54991912841797, zero_point=0
#           (activation_post_process): Identity()
#         )
#         (relu1): Identity()
#         (relu2): Identity()
#       )
#       (18): QuantizableBottleneck(
#         (conv1): QuantizedConvReLU2d(1024, 1024, kernel_size=(1, 1), stride=(1, 1), scale=7.161844730377197, zero_point=0)
#         (bn1): Identity()
#         (conv2): QuantizedConvReLU2d(1024, 1024, kernel_size=(3, 3), stride=(1, 1), scale=19.303253173828125, zero_point=0, padding=(1, 1), groups=64)
#         (bn2): Identity()
#         (conv3): QuantizedConv2d(1024, 1024, kernel_size=(1, 1), stride=(1, 1), scale=38.6937141418457, zero_point=79)
#         (bn3): Identity()
#         (relu): ReLU()
#         (skip_add_relu): QFunctional(
#           scale=129.5084686279297, zero_point=0
#           (activation_post_process): Identity()
#         )
#         (relu1): Identity()
#         (relu2): Identity()
#       )
#       (19): QuantizableBottleneck(
#         (conv1): QuantizedConvReLU2d(1024, 1024, kernel_size=(1, 1), stride=(1, 1), scale=9.266404151916504, zero_point=0)
#         (bn1): Identity()
#         (conv2): QuantizedConvReLU2d(1024, 1024, kernel_size=(3, 3), stride=(1, 1), scale=14.185368537902832, zero_point=0, padding=(1, 1), groups=64)
#         (bn2): Identity()
#         (conv3): QuantizedConv2d(1024, 1024, kernel_size=(1, 1), stride=(1, 1), scale=77.56871795654297, zero_point=48)
#         (bn3): Identity()
#         (relu): ReLU()
#         (skip_add_relu): QFunctional(
#           scale=131.65298461914062, zero_point=0
#           (activation_post_process): Identity()
#         )
#         (relu1): Identity()
#         (relu2): Identity()
#       )
#       (20): QuantizableBottleneck(
#         (conv1): QuantizedConvReLU2d(1024, 1024, kernel_size=(1, 1), stride=(1, 1), scale=13.38179874420166, zero_point=0)
#         (bn1): Identity()
#         (conv2): QuantizedConvReLU2d(1024, 1024, kernel_size=(3, 3), stride=(1, 1), scale=43.842166900634766, zero_point=0, padding=(1, 1), groups=64)
#         (bn2): Identity()
#         (conv3): QuantizedConv2d(1024, 1024, kernel_size=(1, 1), stride=(1, 1), scale=147.5638885498047, zero_point=58)
#         (bn3): Identity()
#         (relu): ReLU()
#         (skip_add_relu): QFunctional(
#           scale=146.27110290527344, zero_point=0
#           (activation_post_process): Identity()
#         )
#         (relu1): Identity()
#         (relu2): Identity()
#       )
#       (21): QuantizableBottleneck(
#         (conv1): QuantizedConvReLU2d(1024, 1024, kernel_size=(1, 1), stride=(1, 1), scale=25.139591217041016, zero_point=0)
#         (bn1): Identity()
#         (conv2): QuantizedConvReLU2d(1024, 1024, kernel_size=(3, 3), stride=(1, 1), scale=45.86544418334961, zero_point=0, padding=(1, 1), groups=64)
#         (bn2): Identity()
#         (conv3): QuantizedConv2d(1024, 1024, kernel_size=(1, 1), stride=(1, 1), scale=303.71844482421875, zero_point=117)
#         (bn3): Identity()
#         (relu): ReLU()
#         (skip_add_relu): QFunctional(
#           scale=87.8735122680664, zero_point=0
#           (activation_post_process): Identity()
#         )
#         (relu1): Identity()
#         (relu2): Identity()
#       )
#       (22): QuantizableBottleneck(
#         (conv1): QuantizedConvReLU2d(1024, 1024, kernel_size=(1, 1), stride=(1, 1), scale=21.909709930419922, zero_point=0)
#         (bn1): Identity()
#         (conv2): QuantizedConvReLU2d(1024, 1024, kernel_size=(3, 3), stride=(1, 1), scale=29.83659553527832, zero_point=0, padding=(1, 1), groups=64)
#         (bn2): Identity()
#         (conv3): QuantizedConv2d(1024, 1024, kernel_size=(1, 1), stride=(1, 1), scale=148.34103393554688, zero_point=100)
#         (bn3): Identity()
#         (relu): ReLU()
#         (skip_add_relu): QFunctional(
#           scale=73.65193939208984, zero_point=0
#           (activation_post_process): Identity()
#         )
#         (relu1): Identity()
#         (relu2): Identity()
#       )
#     )
#     (layer4): Sequential(
#       (0): QuantizableBottleneck(
#         (conv1): QuantizedConvReLU2d(1024, 2048, kernel_size=(1, 1), stride=(1, 1), scale=4.077426910400391, zero_point=0)
#         (bn1): Identity()
#         (conv2): QuantizedConvReLU2d(2048, 2048, kernel_size=(3, 3), stride=(2, 2), scale=13.682212829589844, zero_point=0, padding=(1, 1), groups=64)
#         (bn2): Identity()
#         (conv3): QuantizedConv2d(2048, 2048, kernel_size=(1, 1), stride=(1, 1), scale=25.181772232055664, zero_point=83)
#         (bn3): Identity()
#         (relu): ReLU()
#         (downsample): Sequential(
#           (0): QuantizedConv2d(1024, 2048, kernel_size=(1, 1), stride=(2, 2), scale=27.858102798461914, zero_point=70)
#           (1): Identity()
#         )
#         (skip_add_relu): QFunctional(
#           scale=13.491364479064941, zero_point=0
#           (activation_post_process): Identity()
#         )
#         (relu1): Identity()
#         (relu2): Identity()
#       )
#       (1): QuantizableBottleneck(
#         (conv1): QuantizedConvReLU2d(2048, 2048, kernel_size=(1, 1), stride=(1, 1), scale=2.417527198791504, zero_point=0)
#         (bn1): Identity()
#         (conv2): QuantizedConvReLU2d(2048, 2048, kernel_size=(3, 3), stride=(1, 1), scale=3.7622954845428467, zero_point=0, padding=(1, 1), groups=64)
#         (bn2): Identity()
#         (conv3): QuantizedConv2d(2048, 2048, kernel_size=(1, 1), stride=(1, 1), scale=19.521146774291992, zero_point=69)
#         (bn3): Identity()
#         (relu): ReLU()
#         (skip_add_relu): QFunctional(
#           scale=11.360304832458496, zero_point=0
#           (activation_post_process): Identity()
#         )
#         (relu1): Identity()
#         (relu2): Identity()
#       )
#       (2): QuantizableBottleneck(
#         (conv1): QuantizedConvReLU2d(2048, 2048, kernel_size=(1, 1), stride=(1, 1), scale=2.718116521835327, zero_point=0)
#         (bn1): Identity()
#         (conv2): QuantizedConvReLU2d(2048, 2048, kernel_size=(3, 3), stride=(1, 1), scale=7.21509313583374, zero_point=0, padding=(1, 1), groups=64)
#         (bn2): Identity()
#         (conv3): QuantizedConv2d(2048, 2048, kernel_size=(1, 1), stride=(1, 1), scale=20.28241539001465, zero_point=70)
#         (bn3): Identity()
#         (relu): ReLU()
#         (skip_add_relu): QFunctional(
#           scale=11.603947639465332, zero_point=0
#           (activation_post_process): Identity()
#         )
#         (relu1): Identity()
#         (relu2): Identity()
#       )
#     )
#     (avgpool): AdaptiveAvgPool2d(output_size=(1, 1))
#     (fc): QuantizedLinear(in_features=2048, out_features=1280, scale=0.22753497958183289, zero_point=67, qscheme=torch.per_channel_affine)
#     (quant): Quantize(scale=tensor([8.1437]), zero_point=tensor([0]), dtype=torch.quint8)
#     (dequant): DeQuantize()
#   )
#   (1): G0: (0.000719, 0.796476), G1: (0.000028, 0.817714), G2: (-0.000234, 0.813279)
#   (2): QuantWrapper(
#     (quant): Quantize(scale=tensor([1.4476]), zero_point=tensor([86]), dtype=torch.quint8)
#     (dequant): DeQuantize()
#     (module): QuantizedLinear(in_features=1280, out_features=1, scale=0.16870762407779694, zero_point=34, qscheme=torch.per_channel_affine)
#   )
# )

# %%
qmodel.qconfig
